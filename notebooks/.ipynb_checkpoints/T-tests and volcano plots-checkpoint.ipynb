# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')
# %matplotlib inline

# %%
working_dir = '/media/jswaney/Drive/Justin/organoid_phenotyping'
os.listdir(working_dir)
# Out:
# ['combined_features.xlsx',
#  'cyto_labels_combined.npy',
#  'cyto_profiles_combined.npy',
#  'cyto_profiles_combined_samples.npy',
#  'd35',
#  'd35_vs_d60_sorted.xlsx',
#  'd60',
#  'model_d35_d60_5v5.umap',
#  'old_analysis',
#  'old_datasets']

# %%
df = pd.read_excel(os.path.join(working_dir, 'combined_features.xlsx'))
df = df.set_index('feature')
df.head()
# Out:
#                                      d35 1     d35 2     d35 3     d35 4  \
# feature
# niche DN, celltype sox2, count       109.0      19.0     100.0     201.0
# niche DN, celltype tbr1, count        82.0      23.0      18.0      10.0
# niche DN, celltype dn, count      245387.0   21827.0   57666.0   14236.0
# niche SOX2, celltype sox2, count  899763.0  694432.0  827129.0  808246.0
# niche SOX2, celltype tbr1, count    1727.0    1540.0    2355.0    2515.0
#
#                                       d35 5      d60 1     d60 2     d60 3  \
# feature
# niche DN, celltype sox2, count        218.0     1126.0     489.0     497.0
# niche DN, celltype tbr1, count         91.0      516.0     132.0     159.0
# niche DN, celltype dn, count       188266.0  1945852.0  490586.0  823421.0
# niche SOX2, celltype sox2, count  1170796.0  1514855.0  462003.0  901847.0
# niche SOX2, celltype tbr1, count     4449.0     3247.0     774.0    1493.0
#
#                                       d60 4      d60 5
# feature
# niche DN, celltype sox2, count        685.0      458.0
# niche DN, celltype tbr1, count        281.0       85.0
# niche DN, celltype dn, count      2367183.0   837813.0
# niche SOX2, celltype sox2, count  2165047.0  1269695.0
# niche SOX2, celltype tbr1, count     4104.0     2004.0

# %%
column_headers = list(df.keys())
d35_headers = [h for h in column_headers if 'd35' in h]
d60_headers = [h for h in column_headers if 'd60' in h]

df35 = df[d35_headers]
df60 = df[d60_headers]

df35.head()
# Out:
#                                      d35 1     d35 2     d35 3     d35 4  \
# feature
# niche DN, celltype sox2, count       109.0      19.0     100.0     201.0
# niche DN, celltype tbr1, count        82.0      23.0      18.0      10.0
# niche DN, celltype dn, count      245387.0   21827.0   57666.0   14236.0
# niche SOX2, celltype sox2, count  899763.0  694432.0  827129.0  808246.0
# niche SOX2, celltype tbr1, count    1727.0    1540.0    2355.0    2515.0
#
#                                       d35 5
# feature
# niche DN, celltype sox2, count        218.0
# niche DN, celltype tbr1, count         91.0
# niche DN, celltype dn, count       188266.0
# niche SOX2, celltype sox2, count  1170796.0
# niche SOX2, celltype tbr1, count     4449.0

# %% [markdown]
# Make volcano plots

# %%
d35_means = df35.mean(axis=1)
d60_means = df60.mean(axis=1)

fc = d60_means / d35_means
log2fc = np.log2(fc)

log2fc.head()
# Out:
# feature
# niche DN, celltype sox2, count      2.330820
# niche DN, celltype tbr1, count      2.388632
# niche DN, celltype dn, count        3.615698
# niche SOX2, celltype sox2, count    0.520804
# niche SOX2, celltype tbr1, count   -0.114961
# dtype: float64

# %%
ts = []
pvals = []

for feature in tqdm(df35.index, total=len(df35)):
    a = df35.loc[feature]
    b = df60.loc[feature]
    t, pval = ttest_ind(a, b)
    ts.append(t)
    pvals.append(pval)

t = np.asarray(ts)
pval = np.asarray(pvals)

logp = -np.log10(pval)
# Out:
# HBox(children=(IntProgress(value=0, max=211), HTML(value='')))

# %%
idx_fc = np.where(np.abs(log2fc) > 1)[0]
idx_pval = np.where(pval < 0.05)[0]

idx_keep = np.intersect1d(idx_fc, idx_pval)
idx_drop = np.setdiff1d(np.arange(len(pval)), idx_keep)

print(len(idx_keep))

plt.plot(log2fc[idx_drop], logp[idx_drop], 'b.')
plt.plot(log2fc[idx_keep], logp[idx_keep], 'r.')
plt.xlabel('Fold Change')
plt.ylabel('Log P-val')
plt.xlim([-4, 4])
plt.show()
# Out:
# 14
# /home/jswaney/anaconda3/envs/scout/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less
# <img src="data:image/png;base64,..." width="640">

# %%
for i, f in enumerate(df35.index):
    print(i, f)

# Look at features
# 105 - Start of Cyto
# 165 - Start of Whole Org
# Out:
# 0 niche DN, celltype sox2, count
# 1 niche DN, celltype tbr1, count
# 2 niche DN, celltype dn, count
# 3 niche SOX2, celltype sox2, count
# 4 niche SOX2, celltype tbr1, count
# 5 niche SOX2, celltype dn, count
# 6 niche TBR1, celltype sox2, count
# 7 niche TBR1, celltype tbr1, count
# 8 niche TBR1, celltype dn, count
# 9 niche DP, celltype sox2, count
# 10 niche DP, celltype tbr1, count
# 11 niche DP, celltype dn, count
# 12 niche Intermediate, celltype sox2, count
# 13 niche Intermediate, celltype tbr1, count
# 14 niche Intermediate, celltype dn, count
# 15 niche DN, eq diam mean
# 16 niche DN, eq diam stdev
# 17 niche SOX2, eq diam mean
# 18 niche SOX2, eq diam stdev
# 19 niche TBR1, eq diam mean
# 20 niche TBR1, eq diam stdev
# 21 niche DP, eq diam mean
# 22 niche DP, eq diam stdev
# 23 niche Intermediate, eq diam mean
# 24 niche Intermediate, eq diam stdev
# 25 niche DN, major axis mean
# 26 niche DN, major axis stdev
# 27 niche SOX2, major axis mean
# 28 niche SOX2, major axis stdev
# 29 niche TBR1, major axis mean
# 30 niche TBR1, major axis stdev
# 31 niche DP, major axis mean
# 32 niche DP, major axis stdev
# 33 niche Intermediate, major axis mean
# 34 niche Intermediate, major axis stdev
# 35 niche DN, axis ratio mean
# 36 niche DN, axis ratio stdev
# 37 niche SOX2, axis ratio mean
# 38 niche SOX2, axis ratio stdev
# 39 niche TBR1, axis ratio mean
# 40 niche TBR1, axis ratio stdev
# 41 niche DP, axis ratio mean
# 42 niche DP, axis ratio stdev
# 43 niche Intermediate, axis ratio mean
# 44 niche Intermediate, axis ratio stdev
# 45 niche DN, celltype sox2, SOX2 proximity mean
# 46 niche DN, celltype sox2, SOX2 proximity stdev
# 47 niche DN, celltype sox2, TBR1 proximity mean
# 48 niche DN, celltype sox2, TBR1 proximity stdev
# 49 niche DN, celltype tbr1, SOX2 proximity mean
# 50 niche DN, celltype tbr1, SOX2 proximity stdev
# 51 niche DN, celltype tbr1, TBR1 proximity mean
# 52 niche DN, celltype tbr1, TBR1 proximity stdev
# 53 niche DN, celltype dn, SOX2 proximity mean
# 54 niche DN, celltype dn, SOX2 proximity stdev
# 55 niche DN, celltype dn, TBR1 proximity mean
# 56 niche DN, celltype dn, TBR1 proximity stdev
# 57 niche SOX2, celltype sox2, SOX2 proximity mean
# 58 niche SOX2, celltype sox2, SOX2 proximity stdev
# 59 niche SOX2, celltype sox2, TBR1 proximity mean
# 60 niche SOX2, celltype sox2, TBR1 proximity stdev
# 61 niche SOX2, celltype tbr1, SOX2 proximity mean
# 62 niche SOX2, celltype tbr1, SOX2 proximity stdev
# 63 niche SOX2, celltype tbr1, TBR1 proximity mean
# 64 niche SOX2, celltype tbr1, TBR1 proximity stdev
# 65 niche SOX2, celltype dn, SOX2 proximity mean
# 66 niche SOX2, celltype dn, SOX2 proximity stdev
# 67 niche SOX2, celltype dn, TBR1 proximity mean
# 68 niche SOX2, celltype dn, TBR1 proximity stdev
# 69 niche TBR1, celltype sox2, SOX2 proximity mean
# 70 niche TBR1, celltype sox2, SOX2 proximity stdev
# 71 niche TBR1, celltype sox2, TBR1 proximity mean
# 72 niche TBR1, celltype sox2, TBR1 proximity stdev
# 73 niche TBR1, celltype tbr1, SOX2 proximity mean
# 74 niche TBR1, celltype tbr1, SOX2 proximity stdev
# 75 niche TBR1, celltype tbr1, TBR1 proximity mean
# 76 niche TBR1, celltype tbr1, TBR1 proximity stdev
# 77 niche TBR1, celltype dn, SOX2 proximity mean
# 78 niche TBR1, celltype dn, SOX2 proximity stdev
# 79 niche TBR1, celltype dn, TBR1 proximity mean
# 80 niche TBR1, celltype dn, TBR1 proximity stdev
# 81 niche DP, celltype sox2, SOX2 proximity mean
# 82 niche DP, celltype sox2, SOX2 proximity stdev
# 83 niche DP, celltype sox2, TBR1 proximity mean
# 84 niche DP, celltype sox2, TBR1 proximity stdev
# 85 niche DP, celltype tbr1, SOX2 proximity mean
# 86 niche DP, celltype tbr1, SOX2 proximity stdev
# 87 niche DP, celltype tbr1, TBR1 proximity mean
# 88 niche DP, celltype tbr1, TBR1 proximity stdev
# 89 niche DP, celltype dn, SOX2 proximity mean
# 90 niche DP, celltype dn, SOX2 proximity stdev
# 91 niche DP, celltype dn, TBR1 proximity mean
# 92 niche DP, celltype dn, TBR1 proximity stdev
# 93 niche Intermediate, celltype sox2, SOX2 proximity mean
# 94 niche Intermediate, celltype sox2, SOX2 proximity stdev
# 95 niche Intermediate, celltype sox2, TBR1 proximity mean
# 96 niche Intermediate, celltype sox2, TBR1 proximity stdev
# 97 niche Intermediate, celltype tbr1, SOX2 proximity mean
# 98 niche Intermediate, celltype tbr1, SOX2 proximity stdev
# 99 niche Intermediate, celltype tbr1, TBR1 proximity mean
# 100 niche Intermediate, celltype tbr1, TBR1 proximity stdev
# 101 niche Intermediate, celltype dn, SOX2 proximity mean
# 102 niche Intermediate, celltype dn, SOX2 proximity stdev
# 103 niche Intermediate, celltype dn, TBR1 proximity mean
# 104 niche Intermediate, celltype dn, TBR1 proximity stdev
# 105 cytoarchitecture Trash proportion
# 106 cytoarchitecture Mature proportion
# 107 cytoarchitecture Surface proportion
# 108 cytoarchitecture Empty proportion
# 109 cytoarchitecture Interferring proportion
# 110 cytoarchitecture NoTbr1 proportion
# 111 cytoarchitecture Trash average profile, celltype sox2, count
# 112 cytoarchitecture Trash average profile, celltype tbr1, count
# 113 cytoarchitecture Trash average profile, celltype dn, count
# 114 cytoarchitecture Mature average profile, celltype sox2, count
# 115 cytoarchitecture Mature average profile, celltype tbr1, count
# 116 cytoarchitecture Mature average profile, celltype dn, count
# 117 cytoarchitecture Surface average profile, celltype sox2, count
# 118 cytoarchitecture Surface average profile, celltype tbr1, count
# 119 cytoarchitecture Surface average profile, celltype dn, count
# 120 cytoarchitecture Empty average profile, celltype sox2, count
# 121 cytoarchitecture Empty average profile, celltype tbr1, count
# 122 cytoarchitecture Empty average profile, celltype dn, count
# 123 cytoarchitecture Interferring average profile, celltype sox2, count
# 124 cytoarchitecture Interferring average profile, celltype tbr1, count
# 125 cytoarchitecture Interferring average profile, celltype dn, count
# 126 cytoarchitecture NoTbr1 average profile, celltype sox2, count
# 127 cytoarchitecture NoTbr1 average profile, celltype tbr1, count
# 128 cytoarchitecture NoTbr1 average profile, celltype dn, count
# 129 cytoarchitecture Trash average profile, celltype sox2, profile mean
# 130 cytoarchitecture Trash average profile, celltype tbr1, profile mean
# 131 cytoarchitecture Trash average profile, celltype dn, profile mean
# 132 cytoarchitecture Mature average profile, celltype sox2, profile mean
# 133 cytoarchitecture Mature average profile, celltype tbr1, profile mean
# 134 cytoarchitecture Mature average profile, celltype dn, profile mean
# 135 cytoarchitecture Surface average profile, celltype sox2, profile mean
# 136 cytoarchitecture Surface average profile, celltype tbr1, profile mean
# 137 cytoarchitecture Surface average profile, celltype dn, profile mean
# 138 cytoarchitecture Empty average profile, celltype sox2, profile mean
# 139 cytoarchitecture Empty average profile, celltype tbr1, profile mean
# 140 cytoarchitecture Empty average profile, celltype dn, profile mean
# 141 cytoarchitecture Interferring average profile, celltype sox2, profile mean
# 142 cytoarchitecture Interferring average profile, celltype tbr1, profile mean
# 143 cytoarchitecture Interferring average profile, celltype dn, profile mean
# 144 cytoarchitecture NoTbr1 average profile, celltype sox2, profile mean
# 145 cytoarchitecture NoTbr1 average profile, celltype tbr1, profile mean
# 146 cytoarchitecture NoTbr1 average profile, celltype dn, profile mean
# 147 cytoarchitecture Trash average profile, celltype sox2, profile stdev
# 148 cytoarchitecture Trash average profile, celltype tbr1, profile stdev
# 149 cytoarchitecture Trash average profile, celltype dn, profile stdev
# 150 cytoarchitecture Mature average profile, celltype sox2, profile stdev
# 151 cytoarchitecture Mature average profile, celltype tbr1, profile stdev
# 152 cytoarchitecture Mature average profile, celltype dn, profile stdev
# 153 cytoarchitecture Surface average profile, celltype sox2, profile stdev
# 154 cytoarchitecture Surface average profile, celltype tbr1, profile stdev
# 155 cytoarchitecture Surface average profile, celltype dn, profile stdev
# 156 cytoarchitecture Empty average profile, celltype sox2, profile stdev
# 157 cytoarchitecture Empty average profile, celltype tbr1, profile stdev
# 158 cytoarchitecture Empty average profile, celltype dn, profile stdev
# 159 cytoarchitecture Interferring average profile, celltype sox2, profile stdev
# 160 cytoarchitecture Interferring average profile, celltype tbr1, profile stdev
# 161 cytoarchitecture Interferring average profile, celltype dn, profile stdev
# 162 cytoarchitecture NoTbr1 average profile, celltype sox2, profile stdev
# 163 cytoarchitecture NoTbr1 average profile, celltype tbr1, profile stdev
# 164 cytoarchitecture NoTbr1 average profile, celltype dn, profile stdev
# 165 organoid volume (mm3)
# 166 organoid equivalent diameter (mm)
# 167 organoid major axis (mm)
# 168 organoid minor axis (mm)
# 169 organoid axis ratio
# 170 ventricle count
# 171 ventricle volume mean (um3)
# 172 ventricle volume stdev (um3)
# 173 ventricle equivalent diameter mean (um)
# 174 ventricle equivalent diameter stdev (um)
# 175 ventricle major axis mean (um)
# 176 ventricle major axis stdev (um)
# 177 ventricle minor axis mean (um)
# 178 ventricle minor axis stdev (um)
# 179 ventricle axis ratio mean
# 180 ventricle axis ratio stdev
# 181 niche DN, celltype sox2, surface distance mean (um)
# 182 niche DN, celltype sox2, surface distance stdev (um)
# 183 niche DN, celltype tbr1, surface distance mean (um)
# 184 niche DN, celltype tbr1, surface distance stdev (um)
# 185 niche DN, celltype dn, surface distance mean (um)
# 186 niche DN, celltype dn, surface distance stdev (um)
# 187 niche SOX2, celltype sox2, surface distance mean (um)
# 188 niche SOX2, celltype sox2, surface distance stdev (um)
# 189 niche SOX2, celltype tbr1, surface distance mean (um)
# 190 niche SOX2, celltype tbr1, surface distance stdev (um)
# 191 niche SOX2, celltype dn, surface distance mean (um)
# 192 niche SOX2, celltype dn, surface distance stdev (um)
# 193 niche TBR1, celltype sox2, surface distance mean (um)
# 194 niche TBR1, celltype sox2, surface distance stdev (um)
# 195 niche TBR1, celltype tbr1, surface distance mean (um)
# 196 niche TBR1, celltype tbr1, surface distance stdev (um)
# 197 niche TBR1, celltype dn, surface distance mean (um)
# 198 niche TBR1, celltype dn, surface distance stdev (um)
# 199 niche DP, celltype sox2, surface distance mean (um)
# 200 niche DP, celltype sox2, surface distance stdev (um)
# 201 niche DP, celltype tbr1, surface distance mean (um)
# 202 niche DP, celltype tbr1, surface distance stdev (um)
# 203 niche DP, celltype dn, surface distance mean (um)
# 204 niche DP, celltype dn, surface distance stdev (um)
# 205 niche Intermediate, celltype sox2, surface distance mean (um)
# 206 niche Intermediate, celltype sox2, surface distance stdev (um)
# 207 niche Intermediate, celltype tbr1, surface distance mean (um)
# 208 niche Intermediate, celltype tbr1, surface distance stdev (um)
# 209 niche Intermediate, celltype dn, surface distance mean (um)
# 210 niche Intermediate, celltype dn, surface distance stdev (um)

# %%
cyto_start = 105
wholeorg_start = 165

sns.set_style('ticks')

singlecell_idx = np.arange(cyto_start)
cyto_idx = np.arange(cyto_start, wholeorg_start)
wholeorg_idx = np.arange(wholeorg_start, len(df35.index))

plt.plot(log2fc[singlecell_idx], logp[singlecell_idx], 'b.', label='Single-cell')
plt.plot(log2fc[cyto_idx], logp[cyto_idx], 'r.', label='Cytoarchitecture')
plt.plot(log2fc[wholeorg_idx], logp[wholeorg_idx], 'g.', label='Whole organoid')
# plt.plot([0, 0], [0, 7], 'k-')
plt.xlabel('Fold Change')
plt.ylabel('Log P-val')
plt.legend()
plt.xlim([-4, 4])
plt.ylim([0, 7])
sns.despine()
plt.show()

# %% [markdown]
# Save dataframe with t-test results

# %%
# This will modify df

feature_scale = cyto_start * ['Single-cell'] + (wholeorg_start - cyto_start) * ['Cytoarchitecture'] + (len(df) - wholeorg_start) * ['Whole organoid']
df['scale'] = feature_scale

df['FC'] = fc
df['t'] = t
df['pval'] = pval
df['log2FC'] = log2fc
df['logp'] = logp

df.head()
# Out:
#                                      d35 1     d35 2     d35 3     d35 4  \
# feature
# niche DN, celltype sox2, count       109.0      19.0     100.0     201.0
# niche DN, celltype tbr1, count        82.0      23.0      18.0      10.0
# niche DN, celltype dn, count      245387.0   21827.0   57666.0   14236.0
# niche SOX2, celltype sox2, count  899763.0  694432.0  827129.0  808246.0
# niche SOX2, celltype tbr1, count    1727.0    1540.0    2355.0    2515.0
#
#                                       d35 5      d60 1     d60 2     d60 3  \
# feature
# niche DN, celltype sox2, count        218.0     1126.0     489.0     497.0
# niche DN, celltype tbr1, count         91.0      516.0     132.0     159.0
# niche DN, celltype dn, count       188266.0  1945852.0  490586.0  823421.0
# niche SOX2, celltype sox2, count  1170796.0  1514855.0  462003.0  901847.0
# niche SOX2, celltype tbr1, count     4449.0     3247.0     774.0    1493.0
#
#                                       d60 4      d60 5        scale  \
# feature
# niche DN, celltype sox2, count        685.0      458.0  Single-cell
# niche DN, celltype tbr1, count        281.0       85.0  Single-cell
# niche DN, celltype dn, count      2367183.0   837813.0  Single-cell
# niche SOX2, celltype sox2, count  2165047.0  1269695.0  Single-cell
# niche SOX2, celltype tbr1, count     4104.0     2004.0  Single-cell
#
#                                          FC         t      pval    log2FC  \
# feature
# niche DN, celltype sox2, count     5.030912 -3.997932  0.003961  2.330820
# niche DN, celltype tbr1, count     5.236607 -2.392357  0.043695  2.388632
# niche DN, celltype dn, count      12.258391 -3.234534  0.011975  3.615698
# niche SOX2, celltype sox2, count   1.434755 -1.283786  0.235149  0.520804
# niche SOX2, celltype tbr1, count   0.923407  0.243357  0.813853 -0.114961
#
#                                       logp
# feature
# niche DN, celltype sox2, count    2.402174
# niche DN, celltype tbr1, count    1.359570
# niche DN, celltype dn, count      1.921713
# niche SOX2, celltype sox2, count  0.628657
# niche SOX2, celltype tbr1, count  0.089454

# %%
df.to_excel(os.path.join(working_dir, 'd35_vs_d60_fixed_FC.xlsx'))

# %% [markdown]
# Make swarm plots

# %%
kept_feats = df35.index[idx_keep]
for f, a, b in zip(kept_feats, d35_means[idx_keep], d60_means[idx_keep]):
    if b > a:
        direction = 1
    else:
        direction = -1
    print(f'{f:60s} {a:12.3f} -> {b:12.3f} {direction:4d}')
# Out:
# niche DN, celltype sox2, count                                    129.400 ->      651.000    1
# niche DN, celltype tbr1, count                                     44.800 ->      234.600    1
# niche DN, celltype dn, count                                   105476.400 ->  1292971.000    1
# niche TBR1, celltype sox2, count                                 1144.000 ->     7659.000    1
# niche TBR1, celltype tbr1, count                               379278.600 ->  1262686.600    1
# niche Intermediate, celltype sox2, count                         9429.200 ->    52150.200    1
# niche Intermediate, celltype tbr1, count                        13515.600 ->    68677.600    1
# niche Intermediate, celltype dn, count                         562651.800 ->  2587146.600    1
# cytoarchitecture Mature proportion                                  0.116 ->        0.437    1
# cytoarchitecture Surface proportion                                 0.304 ->        0.117   -1
# cytoarchitecture Interferring proportion                            0.396 ->        0.098   -1
# cytoarchitecture Surface average profile, celltype dn, count       32.354 ->       88.700    1
# organoid volume (mm3)                                               2.877 ->        8.094    1
# ventricle volume mean (um3)                                    655503.971 ->   194112.523   -1

# %%
d35_hits = df35.loc[kept_feats].T
d60_hits = df60.loc[kept_feats].T

# %%
d35_hits['age'] = 'd35'
d60_hits['age'] = 'd60'

df_hits = d35_hits.append(d60_hits)
df_hits['analysis'] = 'organoids'

df_hits
# Out:
# feature  niche DN, celltype sox2, count  niche DN, celltype tbr1, count  \
# d35 1                             109.0                            82.0
# d35 2                              19.0                            23.0
# d35 3                             100.0                            18.0
# d35 4                             201.0                            10.0
# d35 5                             218.0                            91.0
# d60 1                            1126.0                           516.0
# d60 2                             489.0                           132.0
# d60 3                             497.0                           159.0
# d60 4                             685.0                           281.0
# d60 5                             458.0                            85.0
#
# feature  niche DN, celltype dn, count  niche TBR1, celltype sox2, count  \
# d35 1                        245387.0                             618.0
# d35 2                         21827.0                            1065.0
# d35 3                         57666.0                            1273.0
# d35 4                         14236.0                             830.0
# d35 5                        188266.0                            1934.0
# d60 1                       1945852.0                           10661.0
# d60 2                        490586.0                            1710.0
# d60 3                        823421.0                            6569.0
# d60 4                       2367183.0                           13067.0
# d60 5                        837813.0                            6288.0
#
# feature  niche TBR1, celltype tbr1, count  \
# d35 1                            335094.0
# d35 2                            380474.0
# d35 3                            348312.0
# d35 4                            336554.0
# d35 5                            495959.0
# d60 1                           1624941.0
# d60 2                            450699.0
# d60 3                           1321265.0
# d60 4                           1862458.0
# d60 5                           1054070.0
#
# feature  niche Intermediate, celltype sox2, count  \
# d35 1                                      8062.0
# d35 2                                      6341.0
# d35 3                                      6656.0
# d35 4                                      6505.0
# d35 5                                     19582.0
# d60 1                                     85677.0
# d60 2                                     27051.0
# d60 3                                     44871.0
# d60 4                                     61057.0
# d60 5                                     42095.0
#
# feature  niche Intermediate, celltype tbr1, count  \
# d35 1                                     13732.0
# d35 2                                      9375.0
# d35 3                                     10424.0
# d35 4                                     10119.0
# d35 5                                     23928.0
# d60 1                                    116415.0
# d60 2                                     33848.0
# d60 3                                     63131.0
# d60 4                                     68292.0
# d60 5                                     61702.0
#
# feature  niche Intermediate, celltype dn, count  \
# d35 1                                  646228.0
# d35 2                                  518818.0
# d35 3                                  491149.0
# d35 4                                  504064.0
# d35 5                                  653000.0
# d60 1                                 3496546.0
# d60 2                                 1323980.0
# d60 3                                 2145608.0
# d60 4                                 3486376.0
# d60 5                                 2483223.0
#
# feature  cytoarchitecture Mature proportion  \
# d35 1                              0.072356
# d35 2                              0.132053
# d35 3                              0.110623
# d35 4                              0.092423
# d35 5                              0.171694
# d60 1                              0.604813
# d60 2                              0.139438
# d60 3                              0.552967
# d60 4                              0.346740
# d60 5                              0.543109
#
# feature  cytoarchitecture Surface proportion  \
# d35 1                               0.334724
# d35 2                               0.288551
# d35 3                               0.300678
# d35 4                               0.322803
# d35 5                               0.275585
# d60 1                               0.099904
# d60 2                               0.251773
# d60 3                               0.080331
# d60 4                               0.075665
# d60 5                               0.079564
#
# feature  cytoarchitecture Interferring proportion  \
# d35 1                                    0.371783
# d35 2                                    0.429547
# d35 3                                    0.367179
# d35 4                                    0.416422
# d35 5                                    0.392578
# d60 1                                    0.077458
# d60 2                                    0.087766
# d60 3                                    0.070245
# d60 4                                    0.157497
# d60 5                                    0.099452
#
# feature  cytoarchitecture Surface average profile, celltype dn, count  \
# d35 1                                            36.642679
# d35 2                                            34.929378
# d35 3                                            32.126206
# d35 4                                            24.730728
# d35 5                                            33.342052
# d60 1                                            66.881215
# d60 2                                           109.874497
# d60 3                                            77.168885
# d60 4                                            93.016299
# d60 5                                            96.559244
#
# feature  organoid volume (mm3)  ventricle volume mean (um3)  age   analysis
# d35 1                 2.975301                 2.687944e+05  d35  organoids
# d35 2                 1.765713                 4.373650e+05  d35  organoids
# d35 3                 2.151934                 5.116934e+05  d35  organoids
# d35 4                 1.889157                 7.178266e+05  d35  organoids
# d35 5                 5.600509                 1.341840e+06  d35  organoids
# d60 1                 7.104010                 1.632222e+05  d60  organoids
# d60 2                 4.295311                 6.659086e+04  d60  organoids
# d60 3                 8.601389                 1.911176e+05  d60  organoids
# d60 4                12.706417                 1.612993e+05  d60  organoids
# d60 5                 7.763225                 3.883327e+05  d60  organoids

# %%
fig = plt.figure(figsize=(8, 24))

for i, f in enumerate(kept_feats):
    plt.subplot(len(kept_feats), 1, i+1)
    plt.title('p-val: {:.1e}'.format(df['pval'][f]))
    ax = sns.swarmplot(x=f, y='analysis', hue='age', data=df_hits, s=8, figure=fig)
    plt.legend().remove()
    xlim = ax.get_xlim()
    ax.get_yaxis().set_visible(False)
    plt.xlim([0, xlim[1]])
    sns.despine()

fig.tight_layout()
plt.show()

# %% [markdown]
# Radar plots

# %% [markdown]
# Cytoarchitecutre proportions

# %%
[print(f) for f in df.index]
# Out:
# niche DN, celltype sox2, count
# niche DN, celltype tbr1, count
# niche DN, celltype dn, count
# niche SOX2, celltype sox2, count
# niche SOX2, celltype tbr1, count
# niche SOX2, celltype dn, count
# niche TBR1, celltype sox2, count
# niche TBR1, celltype tbr1, count
# niche TBR1, celltype dn, count
# niche DP, celltype sox2, count
# niche DP, celltype tbr1, count
# niche DP, celltype dn, count
# niche Intermediate, celltype sox2, count
# niche Intermediate, celltype tbr1, count
# niche Intermediate, celltype dn, count
# niche DN, eq diam mean
# niche DN, eq diam stdev
# niche SOX2, eq diam mean
# niche SOX2, eq diam stdev
# niche TBR1, eq diam mean
# niche TBR1, eq diam stdev
# niche DP, eq diam mean
# niche DP, eq diam stdev
# niche Intermediate, eq diam mean
# niche Intermediate, eq diam stdev
# niche DN, major axis mean
# niche DN, major axis stdev
# niche SOX2, major axis mean
# niche SOX2, major axis stdev
# niche TBR1, major axis mean
# niche TBR1, major axis stdev
# niche DP, major axis mean
# niche DP, major axis stdev
# niche Intermediate, major axis mean
# niche Intermediate, major axis stdev
# niche DN, axis ratio mean
# niche DN, axis ratio stdev
# niche SOX2, axis ratio mean
# niche SOX2, axis ratio stdev
# niche TBR1, axis ratio mean
# niche TBR1, axis ratio stdev
# niche DP, axis ratio mean
# niche DP, axis ratio stdev
# niche Intermediate, axis ratio mean
# niche Intermediate, axis ratio stdev
# niche DN, celltype sox2, SOX2 proximity mean
# niche DN, celltype sox2, SOX2 proximity stdev
# niche DN, celltype sox2, TBR1 proximity mean
# niche DN, celltype sox2, TBR1 proximity stdev
# niche DN, celltype tbr1, SOX2 proximity mean
# niche DN, celltype tbr1, SOX2 proximity stdev
# niche DN, celltype tbr1, TBR1 proximity mean
# niche DN, celltype tbr1, TBR1 proximity stdev
# niche DN, celltype dn, SOX2 proximity mean
# niche DN, celltype dn, SOX2 proximity stdev
# niche DN, celltype dn, TBR1 proximity mean
# niche DN, celltype dn, TBR1 proximity stdev
# niche SOX2, celltype sox2, SOX2 proximity mean
# niche SOX2, celltype sox2, SOX2 proximity stdev
# niche SOX2, celltype sox2, TBR1 proximity mean
# niche SOX2, celltype sox2, TBR1 proximity stdev
# niche SOX2, celltype tbr1, SOX2 proximity mean
# niche SOX2, celltype tbr1, SOX2 proximity stdev
# niche SOX2, celltype tbr1, TBR1 proximity mean
# niche SOX2, celltype tbr1, TBR1 proximity stdev
# niche SOX2, celltype dn, SOX2 proximity mean
# niche SOX2, celltype dn, SOX2 proximity stdev
# niche SOX2, celltype dn, TBR1 proximity mean
# niche SOX2, celltype dn, TBR1 proximity stdev
# niche TBR1, celltype sox2, SOX2 proximity mean
# niche TBR1, celltype sox2, SOX2 proximity stdev
# niche TBR1, celltype sox2, TBR1 proximity mean
# niche TBR1, celltype sox2, TBR1 proximity stdev
# niche TBR1, celltype tbr1, SOX2 proximity mean
# niche TBR1, celltype tbr1, SOX2 proximity stdev
# niche TBR1, celltype tbr1, TBR1 proximity mean
# niche TBR1, celltype tbr1, TBR1 proximity stdev
# niche TBR1, celltype dn, SOX2 proximity mean
# niche TBR1, celltype dn, SOX2 proximity stdev
# niche TBR1, celltype dn, TBR1 proximity mean
# niche TBR1, celltype dn, TBR1 proximity stdev
# niche DP, celltype sox2, SOX2 proximity mean
# niche DP, celltype sox2, SOX2 proximity stdev
# niche DP, celltype sox2, TBR1 proximity mean
# niche DP, celltype sox2, TBR1 proximity stdev
# niche DP, celltype tbr1, SOX2 proximity mean
# niche DP, celltype tbr1, SOX2 proximity stdev
# niche DP, celltype tbr1, TBR1 proximity mean
# niche DP, celltype tbr1, TBR1 proximity stdev
# niche DP, celltype dn, SOX2 proximity mean
# niche DP, celltype dn, SOX2 proximity stdev
# niche DP, celltype dn, TBR1 proximity mean
# niche DP, celltype dn, TBR1 proximity stdev
# niche Intermediate, celltype sox2, SOX2 proximity mean
# niche Intermediate, celltype sox2, SOX2 proximity stdev
# niche Intermediate, celltype sox2, TBR1 proximity mean
# niche Intermediate, celltype sox2, TBR1 proximity stdev
# niche Intermediate, celltype tbr1, SOX2 proximity mean
# niche Intermediate, celltype tbr1, SOX2 proximity stdev
# niche Intermediate, celltype tbr1, TBR1 proximity mean
# niche Intermediate, celltype tbr1, TBR1 proximity stdev
# niche Intermediate, celltype dn, SOX2 proximity mean
# niche Intermediate, celltype dn, SOX2 proximity stdev
# niche Intermediate, celltype dn, TBR1 proximity mean
# niche Intermediate, celltype dn, TBR1 proximity stdev
# cytoarchitecture Trash proportion
# cytoarchitecture Mature proportion
# cytoarchitecture Surface proportion
# cytoarchitecture Empty proportion
# cytoarchitecture Interferring proportion
# cytoarchitecture NoTbr1 proportion
# cytoarchitecture Trash average profile, celltype sox2, count
# cytoarchitecture Trash average profile, celltype tbr1, count
# cytoarchitecture Trash average profile, celltype dn, count
# cytoarchitecture Mature average profile, celltype sox2, count
# cytoarchitecture Mature average profile, celltype tbr1, count
# cytoarchitecture Mature average profile, celltype dn, count
# cytoarchitecture Surface average profile, celltype sox2, count
# cytoarchitecture Surface average profile, celltype tbr1, count
# cytoarchitecture Surface average profile, celltype dn, count
# cytoarchitecture Empty average profile, celltype sox2, count
# cytoarchitecture Empty average profile, celltype tbr1, count
# cytoarchitecture Empty average profile, celltype dn, count
# cytoarchitecture Interferring average profile, celltype sox2, count
# cytoarchitecture Interferring average profile, celltype tbr1, count
# cytoarchitecture Interferring average profile, celltype dn, count
# cytoarchitecture NoTbr1 average profile, celltype sox2, count
# cytoarchitecture NoTbr1 average profile, celltype tbr1, count
# cytoarchitecture NoTbr1 average profile, celltype dn, count
# cytoarchitecture Trash average profile, celltype sox2, profile mean
# cytoarchitecture Trash average profile, celltype tbr1, profile mean
# cytoarchitecture Trash average profile, celltype dn, profile mean
# cytoarchitecture Mature average profile, celltype sox2, profile mean
# cytoarchitecture Mature average profile, celltype tbr1, profile mean
# cytoarchitecture Mature average profile, celltype dn, profile mean
# cytoarchitecture Surface average profile, celltype sox2, profile mean
# cytoarchitecture Surface average profile, celltype tbr1, profile mean
# cytoarchitecture Surface average profile, celltype dn, profile mean
# cytoarchitecture Empty average profile, celltype sox2, profile mean
# cytoarchitecture Empty average profile, celltype tbr1, profile mean
# cytoarchitecture Empty average profile, celltype dn, profile mean
# cytoarchitecture Interferring average profile, celltype sox2, profile mean
# cytoarchitecture Interferring average profile, celltype tbr1, profile mean
# cytoarchitecture Interferring average profile, celltype dn, profile mean
# cytoarchitecture NoTbr1 average profile, celltype sox2, profile mean
# cytoarchitecture NoTbr1 average profile, celltype tbr1, profile mean
# cytoarchitecture NoTbr1 average profile, celltype dn, profile mean
# cytoarchitecture Trash average profile, celltype sox2, profile stdev
# cytoarchitecture Trash average profile, celltype tbr1, profile stdev
# cytoarchitecture Trash average profile, celltype dn, profile stdev
# cytoarchitecture Mature average profile, celltype sox2, profile stdev
# cytoarchitecture Mature average profile, celltype tbr1, profile stdev
# cytoarchitecture Mature average profile, celltype dn, profile stdev
# cytoarchitecture Surface average profile, celltype sox2, profile stdev
# cytoarchitecture Surface average profile, celltype tbr1, profile stdev
# cytoarchitecture Surface average profile, celltype dn, profile stdev
# cytoarchitecture Empty average profile, celltype sox2, profile stdev
# cytoarchitecture Empty average profile, celltype tbr1, profile stdev
# cytoarchitecture Empty average profile, celltype dn, profile stdev
# cytoarchitecture Interferring average profile, celltype sox2, profile stdev
# cytoarchitecture Interferring average profile, celltype tbr1, profile stdev
# cytoarchitecture Interferring average profile, celltype dn, profile stdev
# cytoarchitecture NoTbr1 average profile, celltype sox2, profile stdev
# cytoarchitecture NoTbr1 average profile, celltype tbr1, profile stdev
# cytoarchitecture NoTbr1 average profile, celltype dn, profile stdev
# organoid volume (mm3)
# organoid equivalent diameter (mm)
# organoid major axis (mm)
# organoid minor axis (mm)
# organoid axis ratio
# ventricle count
# ventricle volume mean (um3)
# ventricle volume stdev (um3)
# ventricle equivalent diameter mean (um)
# ventricle equivalent diameter stdev (um)
# ventricle major axis mean (um)
# ventricle major axis stdev (um)
# ventricle minor axis mean (um)
# ventricle minor axis stdev (um)
# ventricle axis ratio mean
# ventricle axis ratio stdev
# niche DN, celltype sox2, surface distance mean (um)
# niche DN, celltype sox2, surface distance stdev (um)
# niche DN, celltype tbr1, surface distance mean (um)
# niche DN, celltype tbr1, surface distance stdev (um)
# niche DN, celltype dn, surface distance mean (um)
# niche DN, celltype dn, surface distance stdev (um)
# niche SOX2, celltype sox2, surface distance mean (um)
# niche SOX2, celltype sox2, surface distance stdev (um)
# niche SOX2, celltype tbr1, surface distance mean (um)
# niche SOX2, celltype tbr1, surface distance stdev (um)
# niche SOX2, celltype dn, surface distance mean (um)
# niche SOX2, celltype dn, surface distance stdev (um)
# niche TBR1, celltype sox2, surface distance mean (um)
# niche TBR1, celltype sox2, surface distance stdev (um)
# niche TBR1, celltype tbr1, surface distance mean (um)
# niche TBR1, celltype tbr1, surface distance stdev (um)
# niche TBR1, celltype dn, surface distance mean (um)
# niche TBR1, celltype dn, surface distance stdev (um)
# niche DP, celltype sox2, surface distance mean (um)
# niche DP, celltype sox2, surface distance stdev (um)
# niche DP, celltype tbr1, surface distance mean (um)
# niche DP, celltype tbr1, surface distance stdev (um)
# niche DP, celltype dn, surface distance mean (um)
# niche DP, celltype dn, surface distance stdev (um)
# niche Intermediate, celltype sox2, surface distance mean (um)
# niche Intermediate, celltype sox2, surface distance stdev (um)
# niche Intermediate, celltype tbr1, surface distance mean (um)
# niche Intermediate, celltype tbr1, surface distance stdev (um)
# niche Intermediate, celltype dn, surface distance mean (um)
# niche Intermediate, celltype dn, surface distance stdev (um)
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cyto_names = ['Trash',
              'Mature',
              'Surface',
              'Empty',
              'Interferring',
              'NoTbr1']
cyto_features = [f'cytoarchitecture {n} proportion' for n in cyto_names]

d35_cyto = df35.loc[cyto_features].mean(axis=1)
d60_cyto = df60.loc[cyto_features].mean(axis=1)

df_cyto = pd.DataFrame({'d35': d35_cyto,
                        'd60': d60_cyto})
df_cyto
# Out:
#                                                d35       d60
# feature
# cytoarchitecture Trash proportion         0.078732  0.162057
# cytoarchitecture Mature proportion        0.115830  0.437413
# cytoarchitecture Surface proportion       0.304468  0.117448
# cytoarchitecture Empty proportion         0.008037  0.002792
# cytoarchitecture Interferring proportion  0.395502  0.098484
# cytoarchitecture NoTbr1 proportion        0.097431  0.181806

# %%
# number of variable
categories=list(cyto_names)
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0.10, 0.20, 0.30, 0.40], ["10%", "20%", "30%", "40%"], color="grey", size=7)
plt.ylim(0, 0.5)

# Ind1
values = list(df_cyto['d35'].values)
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="d35")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values = list(df_cyto['d60'].values)
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="d60")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

plt.show()

# %% [markdown]
# Feature heatmap / clustermap

# %%
df_imputed = df.fillna(method='backfill')

sns.clustermap(data=df_imputed, 
               method='ward', 
               z_score=0, 
               cmap='coolwarm', 
               vmin=-2,
               vmax=2,
               figsize=(4, 20))
plt.show()

# %% [markdown]
# # Feature correlations

# %%
from itertools import product
from scipy.stats import pearsonr

# %%
features = list(df35.index)
combinations = list(product(features, features))

len(combinations), len(features) ** 2
# Out:
# (44521, 44521)

# %%
corr = []
R = np.zeros((len(features), len(features)))
P = np.zeros((len(features), len(features)))
for combination in tqdm(combinations, total=len(combinations)):
    feat1 = combination[0]
    feat2 = combination[1]
    i = features.index(feat1)
    j = features.index(feat2)
    a = df.loc[feat1]
    b = df.loc[feat2]
    # remove nans
    keep = np.logical_and(~np.isnan(a), ~np.isnan(b))
    a = a[keep]
    b = b[keep]
    r, p = pearsonr(a, b)
#     if np.isclose(r, 1.0):
#         print(feat1 == feat2)
    corr.append(r)
    R[i, j] = r
    P[i, j] = p
corr = np.asarray(corr)
# Out:
# HBox(children=(IntProgress(value=0, max=44521), HTML(value='')))

# %%
df_r = pd.DataFrame(R, index=features, columns=features)
df_r.head()
# Out:
#                                   niche DN, celltype sox2, count  \
# niche DN, celltype sox2, count                          1.000000
# niche DN, celltype tbr1, count                          0.945587
# niche DN, celltype dn, count                            0.870663
# niche SOX2, celltype sox2, count                        0.592118
# niche SOX2, celltype tbr1, count                        0.275049
#
#                                   niche DN, celltype tbr1, count  \
# niche DN, celltype sox2, count                          0.945587
# niche DN, celltype tbr1, count                          1.000000
# niche DN, celltype dn, count                            0.861269
# niche SOX2, celltype sox2, count                        0.624663
# niche SOX2, celltype tbr1, count                        0.366798
#
#                                   niche DN, celltype dn, count  \
# niche DN, celltype sox2, count                        0.870663
# niche DN, celltype tbr1, count                        0.861269
# niche DN, celltype dn, count                          1.000000
# niche SOX2, celltype sox2, count                      0.857332
# niche SOX2, celltype tbr1, count                      0.435293
#
#                                   niche SOX2, celltype sox2, count  \
# niche DN, celltype sox2, count                            0.592118
# niche DN, celltype tbr1, count                            0.624663
# niche DN, celltype dn, count                              0.857332
# niche SOX2, celltype sox2, count                          1.000000
# niche SOX2, celltype tbr1, count                          0.754895
#
#                                   niche SOX2, celltype tbr1, count  \
# niche DN, celltype sox2, count                            0.275049
# niche DN, celltype tbr1, count                            0.366798
# niche DN, celltype dn, count                              0.435293
# niche SOX2, celltype sox2, count                          0.754895
# niche SOX2, celltype tbr1, count                          1.000000
#
#                                   niche SOX2, celltype dn, count  \
# niche DN, celltype sox2, count                          0.257047
# niche DN, celltype tbr1, count                          0.428843
# niche DN, celltype dn, count                            0.610619
# niche SOX2, celltype sox2, count                        0.660587
# niche SOX2, celltype tbr1, count                        0.262581
#
#                                   niche TBR1, celltype sox2, count  \
# niche DN, celltype sox2, count                            0.844256
# niche DN, celltype tbr1, count                            0.811159
# niche DN, celltype dn, count                              0.976975
# niche SOX2, celltype sox2, count                          0.869928
# niche SOX2, celltype tbr1, count                          0.452544
#
#                                   niche TBR1, celltype tbr1, count  \
# niche DN, celltype sox2, count                            0.843379
# niche DN, celltype tbr1, count                            0.804269
# niche DN, celltype dn, count                              0.953295
# niche SOX2, celltype sox2, count                          0.822610
# niche SOX2, celltype tbr1, count                          0.397758
#
#                                   niche TBR1, celltype dn, count  \
# niche DN, celltype sox2, count                          0.694297
# niche DN, celltype tbr1, count                          0.713218
# niche DN, celltype dn, count                            0.903567
# niche SOX2, celltype sox2, count                        0.802063
# niche SOX2, celltype tbr1, count                        0.297509
#
#                                   niche DP, celltype sox2, count  ...  \
# niche DN, celltype sox2, count                          0.102957  ...
# niche DN, celltype tbr1, count                          0.179370  ...
# niche DN, celltype dn, count                            0.512062  ...
# niche SOX2, celltype sox2, count                        0.796107  ...
# niche SOX2, celltype tbr1, count                        0.717308  ...
#
#                                   niche DP, celltype tbr1, surface distance mean (um)  \
# niche DN, celltype sox2, count                                            -0.380145
# niche DN, celltype tbr1, count                                            -0.205154
# niche DN, celltype dn, count                                              -0.260899
# niche SOX2, celltype sox2, count                                          -0.102052
# niche SOX2, celltype tbr1, count                                           0.046129
#
#                                   niche DP, celltype tbr1, surface distance stdev (um)  \
# niche DN, celltype sox2, count                                            -0.061260
# niche DN, celltype tbr1, count                                             0.102283
# niche DN, celltype dn, count                                              -0.029905
# niche SOX2, celltype sox2, count                                          -0.013087
# niche SOX2, celltype tbr1, count                                           0.031045
#
#                                   niche DP, celltype dn, surface distance mean (um)  \
# niche DN, celltype sox2, count                                             0.110177
# niche DN, celltype tbr1, count                                             0.213349
# niche DN, celltype dn, count                                               0.101581
# niche SOX2, celltype sox2, count                                           0.009617
# niche SOX2, celltype tbr1, count                                           0.101390
#
#                                   niche DP, celltype dn, surface distance stdev (um)  \
# niche DN, celltype sox2, count                                             0.193785
# niche DN, celltype tbr1, count                                             0.353330
# niche DN, celltype dn, count                                               0.280586
# niche SOX2, celltype sox2, count                                           0.348422
# niche SOX2, celltype tbr1, count                                           0.299677
#
#                                   niche Intermediate, celltype sox2, surface distance mean (um)  \
# niche DN, celltype sox2, count                                             0.226155
# niche DN, celltype tbr1, count                                             0.292341
# niche DN, celltype dn, count                                               0.318288
# niche SOX2, celltype sox2, count                                           0.250159
# niche SOX2, celltype tbr1, count                                           0.018318
#
#                                   niche Intermediate, celltype sox2, surface distance stdev (um)  \
# niche DN, celltype sox2, count                                             0.470829
# niche DN, celltype tbr1, count                                             0.577041
# niche DN, celltype dn, count                                               0.469938
# niche SOX2, celltype sox2, count                                           0.380736
# niche SOX2, celltype tbr1, count                                           0.201853
#
#                                   niche Intermediate, celltype tbr1, surface distance mean (um)  \
# niche DN, celltype sox2, count                                             0.335725
# niche DN, celltype tbr1, count                                             0.502330
# niche DN, celltype dn, count                                               0.455868
# niche SOX2, celltype sox2, count                                           0.428193
# niche SOX2, celltype tbr1, count                                           0.298874
#
#                                   niche Intermediate, celltype tbr1, surface distance stdev (um)  \
# niche DN, celltype sox2, count                                             0.301117
# niche DN, celltype tbr1, count                                             0.515587
# niche DN, celltype dn, count                                               0.382252
# niche SOX2, celltype sox2, count                                           0.403936
# niche SOX2, celltype tbr1, count                                           0.329998
#
#                                   niche Intermediate, celltype dn, surface distance mean (um)  \
# niche DN, celltype sox2, count                                             0.453317
# niche DN, celltype tbr1, count                                             0.554034
# niche DN, celltype dn, count                                               0.590014
# niche SOX2, celltype sox2, count                                           0.502424
# niche SOX2, celltype tbr1, count                                           0.269131
#
#                                   niche Intermediate, celltype dn, surface distance stdev (um)
# niche DN, celltype sox2, count                                             0.483606
# niche DN, celltype tbr1, count                                             0.622393
# niche DN, celltype dn, count                                               0.500885
# niche SOX2, celltype sox2, count                                           0.440491
# niche SOX2, celltype tbr1, count                                           0.266384
#
# [5 rows x 211 columns]

# %%
# %matplotlib inline
cg = sns.clustermap(df_r, 
                    method='average', 
                    metric='euclidean',
                    cmap='coolwarm')
plt.show()

# %%
for idx in cg.dendrogram_row.reordered_ind:
    print(features[idx])
# Out:
# niche TBR1, celltype dn, count
# niche SOX2, celltype sox2, count
# ventricle count
# cytoarchitecture Mature average profile, celltype tbr1, profile mean
# cytoarchitecture Empty average profile, celltype sox2, count
# cytoarchitecture Interferring average profile, celltype sox2, profile mean
# cytoarchitecture Interferring average profile, celltype dn, profile mean
# niche SOX2, celltype tbr1, TBR1 proximity stdev
# cytoarchitecture Surface average profile, celltype dn, count
# niche DN, celltype sox2, SOX2 proximity mean
# niche Intermediate, celltype sox2, SOX2 proximity stdev
# cytoarchitecture Mature average profile, celltype sox2, profile mean
# niche TBR1, celltype sox2, SOX2 proximity stdev
# cytoarchitecture Interferring average profile, celltype tbr1, profile stdev
# cytoarchitecture NoTbr1 average profile, celltype sox2, profile mean
# niche Intermediate, celltype dn, SOX2 proximity stdev
# ventricle axis ratio mean
# niche DN, celltype sox2, TBR1 proximity mean
# cytoarchitecture NoTbr1 average profile, celltype dn, profile stdev
# niche DN, celltype tbr1, TBR1 proximity mean
# niche SOX2, celltype tbr1, SOX2 proximity stdev
# niche DN, celltype tbr1, count
# organoid axis ratio
# cytoarchitecture Mature proportion
# organoid volume (mm3)
# organoid equivalent diameter (mm)
# organoid minor axis (mm)
# niche DN, celltype sox2, count
# organoid major axis (mm)
# niche Intermediate, celltype sox2, count
# niche Intermediate, celltype tbr1, count
# niche Intermediate, celltype dn, count
# niche DN, celltype dn, count
# niche TBR1, celltype sox2, count
# niche TBR1, celltype tbr1, count
# cytoarchitecture Empty average profile, celltype sox2, profile stdev
# niche SOX2, axis ratio mean
# niche DP, axis ratio mean
# niche DN, celltype sox2, TBR1 proximity stdev
# cytoarchitecture Trash average profile, celltype sox2, count
# cytoarchitecture Mature average profile, celltype dn, count
# cytoarchitecture NoTbr1 proportion
# cytoarchitecture Interferring average profile, celltype dn, count
# cytoarchitecture Trash proportion
# cytoarchitecture Trash average profile, celltype dn, count
# niche DN, celltype tbr1, SOX2 proximity mean
# niche DN, celltype tbr1, SOX2 proximity stdev
# cytoarchitecture Surface average profile, celltype sox2, profile mean
# cytoarchitecture Surface average profile, celltype tbr1, profile stdev
# niche DP, eq diam mean
# niche DP, major axis mean
# niche DN, eq diam mean
# niche DN, major axis mean
# niche SOX2, eq diam mean
# niche Intermediate, eq diam mean
# niche TBR1, major axis mean
# niche TBR1, eq diam mean
# niche SOX2, major axis mean
# niche Intermediate, major axis mean
# cytoarchitecture Empty average profile, celltype tbr1, profile stdev
# cytoarchitecture Empty average profile, celltype dn, profile stdev
# niche SOX2, celltype dn, TBR1 proximity stdev
# niche DP, celltype sox2, count
# niche DP, celltype tbr1, count
# cytoarchitecture Empty proportion
# cytoarchitecture Trash average profile, celltype dn, profile stdev
# niche SOX2, celltype tbr1, count
# cytoarchitecture Surface average profile, celltype tbr1, profile mean
# niche TBR1, celltype sox2, TBR1 proximity stdev
# cytoarchitecture NoTbr1 average profile, celltype dn, count
# cytoarchitecture Interferring average profile, celltype dn, profile stdev
# cytoarchitecture Empty average profile, celltype sox2, profile mean
# niche DP, celltype sox2, SOX2 proximity stdev
# niche DP, celltype tbr1, SOX2 proximity stdev
# cytoarchitecture Surface average profile, celltype dn, profile stdev
# niche Intermediate, celltype dn, TBR1 proximity stdev
# niche DP, celltype dn, SOX2 proximity mean
# niche DP, celltype dn, TBR1 proximity stdev
# niche DP, celltype dn, TBR1 proximity mean
# ventricle axis ratio stdev
# niche DP, celltype dn, SOX2 proximity stdev
# niche TBR1, celltype tbr1, surface distance mean (um)
# niche SOX2, celltype tbr1, surface distance stdev (um)
# niche TBR1, celltype sox2, surface distance stdev (um)
# niche DP, celltype sox2, surface distance stdev (um)
# niche DP, celltype tbr1, surface distance stdev (um)
# niche TBR1, celltype sox2, surface distance mean (um)
# niche SOX2, celltype tbr1, surface distance mean (um)
# niche DP, celltype sox2, surface distance mean (um)
# niche DP, celltype tbr1, surface distance mean (um)
# niche DN, celltype sox2, surface distance stdev (um)
# niche DN, celltype tbr1, surface distance stdev (um)
# niche SOX2, celltype dn, surface distance mean (um)
# niche Intermediate, celltype dn, surface distance mean (um)
# niche Intermediate, celltype sox2, surface distance mean (um)
# niche Intermediate, celltype tbr1, surface distance mean (um)
# niche SOX2, celltype dn, surface distance stdev (um)
# niche Intermediate, celltype sox2, surface distance stdev (um)
# niche Intermediate, celltype dn, surface distance stdev (um)
# niche SOX2, celltype sox2, surface distance mean (um)
# niche TBR1, celltype dn, surface distance mean (um)
# niche DP, celltype dn, surface distance stdev (um)
# niche TBR1, celltype tbr1, surface distance stdev (um)
# niche SOX2, celltype sox2, surface distance stdev (um)
# niche TBR1, celltype dn, surface distance stdev (um)
# niche Intermediate, celltype tbr1, surface distance stdev (um)
# niche DN, celltype dn, surface distance stdev (um)
# niche SOX2, celltype dn, count
# niche DN, celltype dn, surface distance mean (um)
# cytoarchitecture Trash average profile, celltype tbr1, profile stdev
# niche DN, celltype dn, TBR1 proximity stdev
# cytoarchitecture Trash average profile, celltype sox2, profile stdev
# niche Intermediate, celltype sox2, TBR1 proximity stdev
# niche Intermediate, celltype tbr1, TBR1 proximity stdev
# niche DP, celltype dn, surface distance mean (um)
# niche DN, axis ratio mean
# niche DN, celltype tbr1, TBR1 proximity stdev
# niche DN, celltype dn, SOX2 proximity mean
# ventricle volume stdev (um3)
# ventricle major axis mean (um)
# ventricle equivalent diameter mean (um)
# ventricle minor axis mean (um)
# ventricle volume mean (um3)
# ventricle major axis stdev (um)
# ventricle equivalent diameter stdev (um)
# ventricle minor axis stdev (um)
# niche SOX2, celltype tbr1, TBR1 proximity mean
# cytoarchitecture Surface average profile, celltype dn, profile mean
# cytoarchitecture Surface average profile, celltype tbr1, count
# cytoarchitecture NoTbr1 average profile, celltype dn, profile mean
# niche DN, celltype sox2, surface distance mean (um)
# niche DN, celltype tbr1, surface distance mean (um)
# niche Intermediate, axis ratio stdev
# niche TBR1, axis ratio stdev
# niche DP, axis ratio stdev
# niche DP, celltype sox2, TBR1 proximity mean
# niche DP, celltype tbr1, TBR1 proximity mean
# niche SOX2, celltype sox2, SOX2 proximity mean
# niche TBR1, celltype tbr1, TBR1 proximity mean
# niche SOX2, celltype dn, SOX2 proximity mean
# niche SOX2, celltype dn, SOX2 proximity stdev
# niche TBR1, celltype dn, TBR1 proximity mean
# niche TBR1, celltype dn, TBR1 proximity stdev
# niche SOX2, celltype sox2, SOX2 proximity stdev
# niche TBR1, celltype tbr1, TBR1 proximity stdev
# niche DP, celltype sox2, TBR1 proximity stdev
# niche DP, celltype tbr1, TBR1 proximity stdev
# niche DP, celltype dn, count
# niche DN, celltype dn, SOX2 proximity stdev
# niche TBR1, eq diam stdev
# niche TBR1, major axis stdev
# niche Intermediate, eq diam stdev
# niche SOX2, major axis stdev
# niche DP, major axis stdev
# niche Intermediate, major axis stdev
# niche DN, eq diam stdev
# niche DN, major axis stdev
# niche SOX2, eq diam stdev
# niche DP, eq diam stdev
# cytoarchitecture Mature average profile, celltype dn, profile stdev
# cytoarchitecture Interferring average profile, celltype sox2, profile stdev
# cytoarchitecture Mature average profile, celltype tbr1, profile stdev
# cytoarchitecture Surface proportion
# cytoarchitecture Mature average profile, celltype sox2, profile stdev
# niche DN, axis ratio stdev
# niche DN, celltype sox2, SOX2 proximity stdev
# cytoarchitecture Interferring average profile, celltype tbr1, count
# cytoarchitecture NoTbr1 average profile, celltype tbr1, count
# niche DP, celltype sox2, SOX2 proximity mean
# niche DP, celltype tbr1, SOX2 proximity mean
# niche SOX2, celltype tbr1, SOX2 proximity mean
# niche TBR1, celltype sox2, TBR1 proximity mean
# cytoarchitecture Mature average profile, celltype sox2, count
# cytoarchitecture NoTbr1 average profile, celltype sox2, profile stdev
# niche Intermediate, celltype tbr1, SOX2 proximity mean
# niche SOX2, celltype sox2, TBR1 proximity mean
# niche SOX2, celltype dn, TBR1 proximity mean
# niche TBR1, celltype sox2, SOX2 proximity mean
# niche TBR1, celltype tbr1, SOX2 proximity stdev
# niche Intermediate, celltype sox2, SOX2 proximity mean
# niche Intermediate, celltype dn, SOX2 proximity mean
# niche TBR1, celltype dn, SOX2 proximity mean
# niche Intermediate, celltype tbr1, SOX2 proximity stdev
# cytoarchitecture NoTbr1 average profile, celltype tbr1, profile stdev
# cytoarchitecture NoTbr1 average profile, celltype tbr1, profile mean
# niche TBR1, celltype tbr1, SOX2 proximity mean
# cytoarchitecture Interferring proportion
# niche TBR1, celltype dn, SOX2 proximity stdev
# cytoarchitecture Surface average profile, celltype sox2, count
# cytoarchitecture Interferring average profile, celltype sox2, count
# cytoarchitecture Trash average profile, celltype sox2, profile mean
# cytoarchitecture Trash average profile, celltype dn, profile mean
# cytoarchitecture NoTbr1 average profile, celltype sox2, count
# cytoarchitecture Mature average profile, celltype dn, profile mean
# niche DN, celltype dn, TBR1 proximity mean
# niche Intermediate, celltype dn, TBR1 proximity mean
# niche Intermediate, celltype sox2, TBR1 proximity mean
# niche Intermediate, celltype tbr1, TBR1 proximity mean
# cytoarchitecture Trash average profile, celltype tbr1, count
# cytoarchitecture Mature average profile, celltype tbr1, count
# cytoarchitecture Empty average profile, celltype tbr1, count
# niche TBR1, axis ratio mean
# niche Intermediate, axis ratio mean
# niche SOX2, axis ratio stdev
# niche SOX2, celltype sox2, TBR1 proximity stdev
# cytoarchitecture Empty average profile, celltype dn, count
# cytoarchitecture Empty average profile, celltype dn, profile mean
# cytoarchitecture Empty average profile, celltype tbr1, profile mean
# cytoarchitecture Trash average profile, celltype tbr1, profile mean
# cytoarchitecture Interferring average profile, celltype tbr1, profile mean
# cytoarchitecture Surface average profile, celltype sox2, profile stdev

# %%
from scipy.cluster.hierarchy import dendrogram

# %%
# %matplotlib qt
# Out:
# Warning: Cannot change to a different GUI toolkit: qt. Using notebook instead.

# %%
plt.figure(figsize=(9, 32))
ddata = dendrogram(cg.dendrogram_row.linkage,
                   color_threshold=7,
                   labels=features,
                   orientation='left',
                   leaf_font_size=12)

label_colors = {'Single-cell': 'b', 'Cytoarchitecture': 'r', 'Whole organoid': 'g'}
ax = plt.gca()
xlbls = ax.get_ymajorticklabels()
for lbl in xlbls:
    scale = df.loc[lbl.get_text()]['scale']
    lbl.set_color(label_colors[scale])
    
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="648">

# %%
cutoff = 0.99

idx = np.argsort(corr)
comb_sorted = np.asarray(combinations)[idx]
corr_sorted = corr[idx]

# Remove combinations that are on the diagonal
keep_idx = np.asarray([i for i, (f1, f2) in enumerate(comb_sorted) if f1 != f2])
comb_sorted = comb_sorted[keep_idx]
corr_sorted = corr_sorted[keep_idx]

neg_idx = np.where(corr_sorted <= -cutoff)[0]
pos_idx = np.where(corr_sorted >= cutoff)[0]

neg_corr = corr_sorted[neg_idx]
neg_comb = comb_sorted[neg_idx]

pos_corr = corr_sorted[pos_idx[::-1]]
pos_comb = comb_sorted[pos_idx[::-1]]

print('Negatively Correlated r < -0.99:', len(neg_idx))
for n, c in zip(neg_corr, neg_comb):
    print(n)
    print("\t", c[0])
    print("\t", c[1])
    
print('Positively Correlated r > 0.99:', len(pos_idx))
for p, c in zip(pos_corr, pos_comb):
    print(p)
    print("\t", c[0])
    print("\t", c[1])

plt.plot(corr_sorted)
plt.plot([-1e4, len(corr) + 1e4], [cutoff, cutoff], 'r-')
plt.plot([-1e4, len(corr) + 1e4], [-cutoff, -cutoff], 'r-')
plt.ylim([-1, 1])
plt.xlim([-1e3, len(corr) + 1e3])
plt.show()
# Out:
# Negatively Correlated r < -0.99: 2
# -0.9918424502663341
# 	 niche TBR1, celltype sox2, SOX2 proximity mean
# 	 niche TBR1, celltype sox2, SOX2 proximity stdev
# -0.9918424502663341
# 	 niche TBR1, celltype sox2, SOX2 proximity stdev
# 	 niche TBR1, celltype sox2, SOX2 proximity mean
# Positively Correlated r > 0.99: 24
# 0.9999883306292099
# 	 niche DP, celltype sox2, surface distance stdev (um)
# 	 niche DP, celltype tbr1, surface distance stdev (um)
# 0.9999883306292099
# 	 niche DP, celltype tbr1, surface distance stdev (um)
# 	 niche DP, celltype sox2, surface distance stdev (um)
# 0.9999091215748445
# 	 niche DP, celltype sox2, surface distance mean (um)
# 	 niche DP, celltype tbr1, surface distance mean (um)
# 0.9999091215748445
# 	 niche DP, celltype tbr1, surface distance mean (um)
# 	 niche DP, celltype sox2, surface distance mean (um)
# 0.9995569728732345
# 	 niche DP, celltype tbr1, count
# 	 niche DP, celltype sox2, count
# 0.9995569728732345
# 	 niche DP, celltype sox2, count
# 	 niche DP, celltype tbr1, count
# 0.9988579480589956
# 	 niche DP, celltype sox2, SOX2 proximity mean
# 	 niche DP, celltype tbr1, SOX2 proximity mean
# 0.9988579480589956
# 	 niche DP, celltype tbr1, SOX2 proximity mean
# 	 niche DP, celltype sox2, SOX2 proximity mean
# 0.9986321534179731
# 	 ventricle equivalent diameter mean (um)
# 	 ventricle minor axis mean (um)
# 0.9986321534179731
# 	 ventricle minor axis mean (um)
# 	 ventricle equivalent diameter mean (um)
# 0.9980020942905115
# 	 niche TBR1, celltype dn, TBR1 proximity stdev
# 	 niche TBR1, celltype dn, TBR1 proximity mean
# 0.9980020942905115
# 	 niche TBR1, celltype dn, TBR1 proximity mean
# 	 niche TBR1, celltype dn, TBR1 proximity stdev
# 0.9937827427812715
# 	 niche DP, celltype sox2, TBR1 proximity mean
# 	 niche DP, celltype tbr1, TBR1 proximity mean
# 0.9937827427812715
# 	 niche DP, celltype tbr1, TBR1 proximity mean
# 	 niche DP, celltype sox2, TBR1 proximity mean
# 0.9916138774063277
# 	 niche DP, celltype sox2, SOX2 proximity stdev
# 	 niche DP, celltype tbr1, SOX2 proximity stdev
# 0.9916138774063277
# 	 niche DP, celltype tbr1, SOX2 proximity stdev
# 	 niche DP, celltype sox2, SOX2 proximity stdev
# 0.990990946981138
# 	 niche DN, major axis stdev
# 	 niche DN, eq diam stdev
# 0.990990946981138
# 	 niche DN, eq diam stdev
# 	 niche DN, major axis stdev
# 0.990924308415296
# 	 niche Intermediate, celltype sox2, SOX2 proximity mean
# 	 niche Intermediate, celltype dn, SOX2 proximity mean
# 0.990924308415296
# 	 niche Intermediate, celltype dn, SOX2 proximity mean
# 	 niche Intermediate, celltype sox2, SOX2 proximity mean
# 0.990402323610938
# 	 niche TBR1, celltype sox2, count
# 	 niche TBR1, celltype tbr1, count
# 0.990402323610938
# 	 niche TBR1, celltype tbr1, count
# 	 niche TBR1, celltype sox2, count
# 0.9902919222774045
# 	 organoid equivalent diameter (mm)
# 	 organoid minor axis (mm)
# 0.9902919222774045
# 	 organoid minor axis (mm)
# 	 organoid equivalent diameter (mm)

# %% [markdown]
# Look at correlations between features in two specific length scales

# %%
features1 = features[:cyto_start]
features2 = features[cyto_start:wholeorg_start]

combinations = list(product(features1, features2))
len(combinations)
# Out:
# 6300

# %%
R = np.zeros((len(features1), len(features2)))
P = np.zeros((len(features1), len(features2)))
for combination in tqdm(combinations, total=len(combinations)):
    feat1 = combination[0]
    feat2 = combination[1]
    i = features1.index(feat1)
    j = features2.index(feat2)
    a = df.loc[feat1]
    b = df.loc[feat2]
    # remove nans
    keep = np.logical_and(~np.isnan(a), ~np.isnan(b))
    a = a[keep]
    b = b[keep]
    r, p = pearsonr(a, b)
    R[i, j] = r
    P[i, j] = p
# Out:
# HBox(children=(IntProgress(value=0, max=6300), HTML(value='')))

# %%
# %matplotlib inline

df_r = pd.DataFrame(R, index=features1, columns=features2)

cg = sns.clustermap(df_r, 
                    method='average', 
                    metric='euclidean',
                    cmap='coolwarm',
                    figsize=(24, 24))
plt.tight_layout()
plt.show()
