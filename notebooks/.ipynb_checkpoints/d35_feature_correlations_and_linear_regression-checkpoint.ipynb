# %% [markdown]
# Discussion with Alex:
# - Differential correlation analysis may lead to cool network graphs but be difficult to interpret
# - Instead, do correlation analysis on multiscale features to show relationships across scales (as expected)
#     - Create a clustered heatmap of pairwise correlations
#     - Try to visualize these relationships in a force-directed graph using pyvis
# - Perform a linear regression analysis on a few high-level organoid features using lower-level features
#     - Organoid size, # ventricles, Ventricle volume

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scout.utils import read_csv

# %%
working_dir = '/data/datasets/organoid_phenotyping/analysis/d35_vs_d60/'

analysis = pd.read_csv(os.path.join(working_dir, 'analysis.csv'), index_col=0)
# features = pd.read_excel(os.path.join(working_dir, 'combined_features.xlsx'), index_col=0)
# features.keys()
analysis.head()
# Out:
#                                                              type
# path
# 20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60  Lancaster_d35
# 20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60  Lancaster_d35
# 20190419_16_09_03_AA_org3_488LP13_561LP120_642LP60  Lancaster_d35
# 20190430_11_36_09_AA-4.30.19-org1_488LP12p5_561...  Lancaster_d35
# 20190430_15_06_10_AA-4.30.19-org3_488LP13_561LP...  Lancaster_d35

# %%
data = {}
for foldername in analysis.index:
    if analysis.loc[foldername]['type'] == 'Lancaster_d35':
        feats = pd.read_excel(os.path.join(working_dir, 
                                           'Lancaster_d35', 
                                           foldername, 
                                           'organoid_features.xlsx'), 
                              index_col=0, 
                              skiprows=1)
        data[foldername] = feats['.']
df = pd.DataFrame(data, index=feats.index)
df.head()
# Out:
#                         20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                174.0
# DN nbrhd, tbr1 count                                                110.0
# DN nbrhd, dn count                                               257563.0
# SOX2 nbrhd, sox2 count                                           550868.0
# SOX2 nbrhd, tbr1 count                                             1296.0
#
#                         20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                 30.0
# DN nbrhd, tbr1 count                                                 37.0
# DN nbrhd, dn count                                               112764.0
# SOX2 nbrhd, sox2 count                                           362686.0
# SOX2 nbrhd, tbr1 count                                              435.0
#
#                         20190419_16_09_03_AA_org3_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                162.0
# DN nbrhd, tbr1 count                                                 50.0
# DN nbrhd, dn count                                               135904.0
# SOX2 nbrhd, sox2 count                                           471401.0
# SOX2 nbrhd, tbr1 count                                             1003.0
#
#                         20190430_11_36_09_AA-4.30.19-org1_488LP12p5_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                189.0
# DN nbrhd, tbr1 count                                                 21.0
# DN nbrhd, dn count                                                83305.0
# SOX2 nbrhd, sox2 count                                           494048.0
# SOX2 nbrhd, tbr1 count                                              672.0
#
#                         20190430_15_06_10_AA-4.30.19-org3_488LP13_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                345.0
# DN nbrhd, tbr1 count                                                105.0
# DN nbrhd, dn count                                               296077.0
# SOX2 nbrhd, sox2 count                                           833321.0
# SOX2 nbrhd, tbr1 count                                             2094.0
#
#                         20190614_14_03_07_AA_ef23-1_488LP14_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                121.0
# DN nbrhd, tbr1 count                                                 63.0
# DN nbrhd, dn count                                                95223.0
# SOX2 nbrhd, sox2 count                                           218660.0
# SOX2 nbrhd, tbr1 count                                              838.0
#
#                         20190614_14_48_43_AA_ef23-2_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                207.0
# DN nbrhd, tbr1 count                                                171.0
# DN nbrhd, dn count                                               471900.0
# SOX2 nbrhd, sox2 count                                           634230.0
# SOX2 nbrhd, tbr1 count                                             2572.0
#
#                         20190614_15_40_09_AA_ef23-3_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                162.0
# DN nbrhd, tbr1 count                                                143.0
# DN nbrhd, dn count                                               556212.0
# SOX2 nbrhd, sox2 count                                           707343.0
# SOX2 nbrhd, tbr1 count                                             1652.0
#
#                         20190614_17_14_47_AA_ef23-4_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                145.0
# DN nbrhd, tbr1 count                                                106.0
# DN nbrhd, dn count                                               341938.0
# SOX2 nbrhd, sox2 count                                           462029.0
# SOX2 nbrhd, tbr1 count                                             1256.0
#
#                         20190614_17_55_05_AA_ef23-5_488LP15_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                103.0
# DN nbrhd, tbr1 count                                                 31.0
# DN nbrhd, dn count                                                92981.0
# SOX2 nbrhd, sox2 count                                           134363.0
# SOX2 nbrhd, tbr1 count                                              498.0
#
#                         20190614_18_12_44_AA_ef23-6_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                               1704.0
# DN nbrhd, tbr1 count                                                538.0
# DN nbrhd, dn count                                                79213.0
# SOX2 nbrhd, sox2 count                                           350636.0
# SOX2 nbrhd, tbr1 count                                             1715.0
#
#                         20190614_18_27_34_AA_ef23-7_488LP14_561LP120_642LP50
# input
# DN nbrhd, sox2 count                                                165.0
# DN nbrhd, tbr1 count                                                 68.0
# DN nbrhd, dn count                                                76304.0
# SOX2 nbrhd, sox2 count                                            85757.0
# SOX2 nbrhd, tbr1 count                                              686.0

# %% [markdown]
# Show correlation heatmap

# %%
from itertools import product
from scipy.stats import pearsonr
from tqdm import tqdm_notebook as tqdm

# %%
features = list(df.index)
combinations = list(product(features, features))

len(combinations), len(features) ** 2
# Out:
# (75625, 75625)

# %%
df_imputed = df.fillna(method='backfill')

# %%
corr = []
R = np.zeros((len(features), len(features)))
P = np.zeros((len(features), len(features)))
for combination in tqdm(combinations, total=len(combinations)):
    feat1 = combination[0]
    feat2 = combination[1]
    i = features.index(feat1)
    j = features.index(feat2)
    a = df_imputed.loc[feat1]
    b = df_imputed.loc[feat2]
    # remove nans
    keep = np.logical_and(~np.isnan(a), ~np.isnan(b))
    a = a[keep]
    b = b[keep]
    r, p = pearsonr(a, b)
#     if np.isclose(r, 1.0):
#         print(feat1 == feat2)
    corr.append(r)
    R[i, j] = r
    P[i, j] = p
corr = np.asarray(corr)
# Out:
# HBox(children=(IntProgress(value=0, max=75625), HTML(value='')))

# %%
df_r = pd.DataFrame(R, index=features, columns=features)
df_r.head()
# Out:
#                         DN nbrhd, sox2 count  DN nbrhd, tbr1 count  \
# DN nbrhd, sox2 count                1.000000              0.954367
# DN nbrhd, tbr1 count                0.954367              1.000000
# DN nbrhd, dn count                 -0.199620              0.049601
# SOX2 nbrhd, sox2 count             -0.019377              0.082138
# SOX2 nbrhd, tbr1 count              0.336926              0.505439
#
#                         DN nbrhd, dn count  SOX2 nbrhd, sox2 count  \
# DN nbrhd, sox2 count             -0.199620               -0.019377
# DN nbrhd, tbr1 count              0.049601                0.082138
# DN nbrhd, dn count                1.000000                0.730263
# SOX2 nbrhd, sox2 count            0.730263                1.000000
# SOX2 nbrhd, tbr1 count            0.716045                0.722701
#
#                         SOX2 nbrhd, tbr1 count  SOX2 nbrhd, dn count  \
# DN nbrhd, sox2 count                  0.336926             -0.350280
# DN nbrhd, tbr1 count                  0.505439             -0.175283
# DN nbrhd, dn count                    0.716045              0.836952
# SOX2 nbrhd, sox2 count                0.722701              0.820693
# SOX2 nbrhd, tbr1 count                1.000000              0.491199
#
#                         TBR1 nbrhd, sox2 count  TBR1 nbrhd, tbr1 count  \
# DN nbrhd, sox2 count                  0.703487                0.004710
# DN nbrhd, tbr1 count                  0.848011                0.046384
# DN nbrhd, dn count                    0.343415                0.552404
# SOX2 nbrhd, sox2 count                0.130797                0.950739
# SOX2 nbrhd, tbr1 count                0.678576                0.659955
#
#                         TBR1 nbrhd, dn count  DP nbrhd, sox2 count  ...  \
# DN nbrhd, sox2 count               -0.131019             -0.052395  ...
# DN nbrhd, tbr1 count               -0.233287              0.190243  ...
# DN nbrhd, dn count                  0.049301              0.761928  ...
# SOX2 nbrhd, sox2 count              0.597832              0.334823  ...
# SOX2 nbrhd, tbr1 count             -0.014790              0.720872  ...
#
#                         MidSOX2 nbrhd, tbr1 surface distance mean (um)  \
# DN nbrhd, sox2 count                                         -0.352491
# DN nbrhd, tbr1 count                                         -0.303633
# DN nbrhd, dn count                                           -0.073082
# SOX2 nbrhd, sox2 count                                       -0.249730
# SOX2 nbrhd, tbr1 count                                       -0.135613
#
#                         MidSOX2 nbrhd, tbr1 surface distance stdev (um)  \
# DN nbrhd, sox2 count                                          -0.354915
# DN nbrhd, tbr1 count                                          -0.394243
# DN nbrhd, dn count                                            -0.137304
# SOX2 nbrhd, sox2 count                                        -0.158314
# SOX2 nbrhd, tbr1 count                                        -0.086323
#
#                         MidSOX2 nbrhd, dn surface distance mean (um)  \
# DN nbrhd, sox2 count                                       -0.327927
# DN nbrhd, tbr1 count                                       -0.223079
# DN nbrhd, dn count                                          0.344807
# SOX2 nbrhd, sox2 count                                      0.443737
# SOX2 nbrhd, tbr1 count                                      0.280416
#
#                         MidSOX2 nbrhd, dn surface distance stdev (um)  \
# DN nbrhd, sox2 count                                        -0.313090
# DN nbrhd, tbr1 count                                        -0.250921
# DN nbrhd, dn count                                           0.339905
# SOX2 nbrhd, sox2 count                                       0.584162
# SOX2 nbrhd, tbr1 count                                       0.358465
#
#                         MidInter nbrhd, sox2 surface distance mean (um)  \
# DN nbrhd, sox2 count                                          -0.317146
# DN nbrhd, tbr1 count                                          -0.223777
# DN nbrhd, dn count                                             0.396921
# SOX2 nbrhd, sox2 count                                         0.583540
# SOX2 nbrhd, tbr1 count                                         0.417899
#
#                         MidInter nbrhd, sox2 surface distance stdev (um)  \
# DN nbrhd, sox2 count                                           -0.283460
# DN nbrhd, tbr1 count                                           -0.208389
# DN nbrhd, dn count                                              0.383883
# SOX2 nbrhd, sox2 count                                          0.614504
# SOX2 nbrhd, tbr1 count                                          0.361180
#
#                         MidInter nbrhd, tbr1 surface distance mean (um)  \
# DN nbrhd, sox2 count                                          -0.359931
# DN nbrhd, tbr1 count                                          -0.258082
# DN nbrhd, dn count                                             0.421251
# SOX2 nbrhd, sox2 count                                         0.575163
# SOX2 nbrhd, tbr1 count                                         0.386193
#
#                         MidInter nbrhd, tbr1 surface distance stdev (um)  \
# DN nbrhd, sox2 count                                           -0.291388
# DN nbrhd, tbr1 count                                           -0.212562
# DN nbrhd, dn count                                              0.390418
# SOX2 nbrhd, sox2 count                                          0.608026
# SOX2 nbrhd, tbr1 count                                          0.357931
#
#                         MidInter nbrhd, dn surface distance mean (um)  \
# DN nbrhd, sox2 count                                        -0.337293
# DN nbrhd, tbr1 count                                        -0.256713
# DN nbrhd, dn count                                           0.375177
# SOX2 nbrhd, sox2 count                                       0.581337
# SOX2 nbrhd, tbr1 count                                       0.396220
#
#                         MidInter nbrhd, dn surface distance stdev (um)
# DN nbrhd, sox2 count                                         -0.300154
# DN nbrhd, tbr1 count                                         -0.241259
# DN nbrhd, dn count                                            0.317339
# SOX2 nbrhd, sox2 count                                        0.571322
# SOX2 nbrhd, tbr1 count                                        0.323045
#
# [5 rows x 275 columns]

# %%
for i, f in enumerate(features):
    print(i, f)
# Out:
# 0 DN nbrhd, sox2 count
# 1 DN nbrhd, tbr1 count
# 2 DN nbrhd, dn count
# 3 SOX2 nbrhd, sox2 count
# 4 SOX2 nbrhd, tbr1 count
# 5 SOX2 nbrhd, dn count
# 6 TBR1 nbrhd, sox2 count
# 7 TBR1 nbrhd, tbr1 count
# 8 TBR1 nbrhd, dn count
# 9 DP nbrhd, sox2 count
# 10 DP nbrhd, tbr1 count
# 11 DP nbrhd, dn count
# 12 MidTBR1 nbrhd, sox2 count
# 13 MidTBR1 nbrhd, tbr1 count
# 14 MidTBR1 nbrhd, dn count
# 15 MidSOX2 nbrhd, sox2 count
# 16 MidSOX2 nbrhd, tbr1 count
# 17 MidSOX2 nbrhd, dn count
# 18 MidInter nbrhd, sox2 count
# 19 MidInter nbrhd, tbr1 count
# 20 MidInter nbrhd, dn count
# 21 DN nbrhd fraction
# 22 SOX2 nbrhd fraction
# 23 TBR1 nbrhd fraction
# 24 DP nbrhd fraction
# 25 MidTBR1 nbrhd fraction
# 26 MidSOX2 nbrhd fraction
# 27 MidInter nbrhd fraction
# 28 TBR1 / SOX2 ratio
# 29 MidTBR1 / MidSOX2 ratio
# 30 MidInter / DN ratio
# 31 DN nbrhd, eq diam mean
# 32 DN nbrhd, eq diam stdev
# 33 SOX2 nbrhd, eq diam mean
# 34 SOX2 nbrhd, eq diam stdev
# 35 TBR1 nbrhd, eq diam mean
# 36 TBR1 nbrhd, eq diam stdev
# 37 DP nbrhd, eq diam mean
# 38 DP nbrhd, eq diam stdev
# 39 MidTBR1 nbrhd, eq diam mean
# 40 MidTBR1 nbrhd, eq diam stdev
# 41 MidSOX2 nbrhd, eq diam mean
# 42 MidSOX2 nbrhd, eq diam stdev
# 43 MidInter nbrhd, eq diam mean
# 44 MidInter nbrhd, eq diam stdev
# 45 DN nbrhd, major axis mean
# 46 DN nbrhd, major axis stdev
# 47 SOX2 nbrhd, major axis mean
# 48 SOX2 nbrhd, major axis stdev
# 49 TBR1 nbrhd, major axis mean
# 50 TBR1 nbrhd, major axis stdev
# 51 DP nbrhd, major axis mean
# 52 DP nbrhd, major axis stdev
# 53 MidTBR1 nbrhd, major axis mean
# 54 MidTBR1 nbrhd, major axis stdev
# 55 MidSOX2 nbrhd, major axis mean
# 56 MidSOX2 nbrhd, major axis stdev
# 57 MidInter nbrhd, major axis mean
# 58 MidInter nbrhd, major axis stdev
# 59 DN nbrhd, axis ratio mean
# 60 DN nbrhd, axis ratio stdev
# 61 SOX2 nbrhd, axis ratio mean
# 62 SOX2 nbrhd, axis ratio stdev
# 63 TBR1 nbrhd, axis ratio mean
# 64 TBR1 nbrhd, axis ratio stdev
# 65 DP nbrhd, axis ratio mean
# 66 DP nbrhd, axis ratio stdev
# 67 MidTBR1 nbrhd, axis ratio mean
# 68 MidTBR1 nbrhd, axis ratio stdev
# 69 MidSOX2 nbrhd, axis ratio mean
# 70 MidSOX2 nbrhd, axis ratio stdev
# 71 MidInter nbrhd, axis ratio mean
# 72 MidInter nbrhd, axis ratio stdev
# 73 DN nbrhd, sox2 proximity to SOX2 mean
# 74 DN nbrhd, sox2 proximity to SOX2 stdev
# 75 DN nbrhd, sox2 proximity to TBR1 mean
# 76 DN nbrhd, sox2 proximity to TBR1 stdev
# 77 DN nbrhd, tbr1 proximity to SOX2 mean
# 78 DN nbrhd, tbr1 proximity to SOX2 stdev
# 79 DN nbrhd, tbr1 proximity to TBR1 mean
# 80 DN nbrhd, tbr1 proximity to TBR1 stdev
# 81 DN nbrhd, dn proximity to SOX2 mean
# 82 DN nbrhd, dn proximity to SOX2 stdev
# 83 DN nbrhd, dn proximity to TBR1 mean
# 84 DN nbrhd, dn proximity to TBR1 stdev
# 85 SOX2 nbrhd, sox2 proximity to SOX2 mean
# 86 SOX2 nbrhd, sox2 proximity to SOX2 stdev
# 87 SOX2 nbrhd, sox2 proximity to TBR1 mean
# 88 SOX2 nbrhd, sox2 proximity to TBR1 stdev
# 89 SOX2 nbrhd, tbr1 proximity to SOX2 mean
# 90 SOX2 nbrhd, tbr1 proximity to SOX2 stdev
# 91 SOX2 nbrhd, tbr1 proximity to TBR1 mean
# 92 SOX2 nbrhd, tbr1 proximity to TBR1 stdev
# 93 SOX2 nbrhd, dn proximity to SOX2 mean
# 94 SOX2 nbrhd, dn proximity to SOX2 stdev
# 95 SOX2 nbrhd, dn proximity to TBR1 mean
# 96 SOX2 nbrhd, dn proximity to TBR1 stdev
# 97 TBR1 nbrhd, sox2 proximity to SOX2 mean
# 98 TBR1 nbrhd, sox2 proximity to SOX2 stdev
# 99 TBR1 nbrhd, sox2 proximity to TBR1 mean
# 100 TBR1 nbrhd, sox2 proximity to TBR1 stdev
# 101 TBR1 nbrhd, tbr1 proximity to SOX2 mean
# 102 TBR1 nbrhd, tbr1 proximity to SOX2 stdev
# 103 TBR1 nbrhd, tbr1 proximity to TBR1 mean
# 104 TBR1 nbrhd, tbr1 proximity to TBR1 stdev
# 105 TBR1 nbrhd, dn proximity to SOX2 mean
# 106 TBR1 nbrhd, dn proximity to SOX2 stdev
# 107 TBR1 nbrhd, dn proximity to TBR1 mean
# 108 TBR1 nbrhd, dn proximity to TBR1 stdev
# 109 DP nbrhd, sox2 proximity to SOX2 mean
# 110 DP nbrhd, sox2 proximity to SOX2 stdev
# 111 DP nbrhd, sox2 proximity to TBR1 mean
# 112 DP nbrhd, sox2 proximity to TBR1 stdev
# 113 DP nbrhd, tbr1 proximity to SOX2 mean
# 114 DP nbrhd, tbr1 proximity to SOX2 stdev
# 115 DP nbrhd, tbr1 proximity to TBR1 mean
# 116 DP nbrhd, tbr1 proximity to TBR1 stdev
# 117 DP nbrhd, dn proximity to SOX2 mean
# 118 DP nbrhd, dn proximity to SOX2 stdev
# 119 DP nbrhd, dn proximity to TBR1 mean
# 120 DP nbrhd, dn proximity to TBR1 stdev
# 121 MidTBR1 nbrhd, sox2 proximity to SOX2 mean
# 122 MidTBR1 nbrhd, sox2 proximity to SOX2 stdev
# 123 MidTBR1 nbrhd, sox2 proximity to TBR1 mean
# 124 MidTBR1 nbrhd, sox2 proximity to TBR1 stdev
# 125 MidTBR1 nbrhd, tbr1 proximity to SOX2 mean
# 126 MidTBR1 nbrhd, tbr1 proximity to SOX2 stdev
# 127 MidTBR1 nbrhd, tbr1 proximity to TBR1 mean
# 128 MidTBR1 nbrhd, tbr1 proximity to TBR1 stdev
# 129 MidTBR1 nbrhd, dn proximity to SOX2 mean
# 130 MidTBR1 nbrhd, dn proximity to SOX2 stdev
# 131 MidTBR1 nbrhd, dn proximity to TBR1 mean
# 132 MidTBR1 nbrhd, dn proximity to TBR1 stdev
# 133 MidSOX2 nbrhd, sox2 proximity to SOX2 mean
# 134 MidSOX2 nbrhd, sox2 proximity to SOX2 stdev
# 135 MidSOX2 nbrhd, sox2 proximity to TBR1 mean
# 136 MidSOX2 nbrhd, sox2 proximity to TBR1 stdev
# 137 MidSOX2 nbrhd, tbr1 proximity to SOX2 mean
# 138 MidSOX2 nbrhd, tbr1 proximity to SOX2 stdev
# 139 MidSOX2 nbrhd, tbr1 proximity to TBR1 mean
# 140 MidSOX2 nbrhd, tbr1 proximity to TBR1 stdev
# 141 MidSOX2 nbrhd, dn proximity to SOX2 mean
# 142 MidSOX2 nbrhd, dn proximity to SOX2 stdev
# 143 MidSOX2 nbrhd, dn proximity to TBR1 mean
# 144 MidSOX2 nbrhd, dn proximity to TBR1 stdev
# 145 MidInter nbrhd, sox2 proximity to SOX2 mean
# 146 MidInter nbrhd, sox2 proximity to SOX2 stdev
# 147 MidInter nbrhd, sox2 proximity to TBR1 mean
# 148 MidInter nbrhd, sox2 proximity to TBR1 stdev
# 149 MidInter nbrhd, tbr1 proximity to SOX2 mean
# 150 MidInter nbrhd, tbr1 proximity to SOX2 stdev
# 151 MidInter nbrhd, tbr1 proximity to TBR1 mean
# 152 MidInter nbrhd, tbr1 proximity to TBR1 stdev
# 153 MidInter nbrhd, dn proximity to SOX2 mean
# 154 MidInter nbrhd, dn proximity to SOX2 stdev
# 155 MidInter nbrhd, dn proximity to TBR1 mean
# 156 MidInter nbrhd, dn proximity to TBR1 stdev
# 157 TBR1-LowDN cytoarchitecture fraction
# 158 TBR1-HighDN cytoarchitecture fraction
# 159 Surface cytoarchitecture fraction
# 160 Artifacts cytoarchitecture fraction
# 161 DN cytoarchitecture fraction
# 162 Adjacent cytoarchitecture fraction
# 163 ave. TBR1-LowDN profile, sox2 count
# 164 ave. TBR1-LowDN profile, tbr1 count
# 165 ave. TBR1-LowDN profile, dn count
# 166 ave. TBR1-HighDN profile, sox2 count
# 167 ave. TBR1-HighDN profile, tbr1 count
# 168 ave. TBR1-HighDN profile, dn count
# 169 ave. Surface profile, sox2 count
# 170 ave. Surface profile, tbr1 count
# 171 ave. Surface profile, dn count
# 172 ave. Artifacts profile, sox2 count
# 173 ave. Artifacts profile, tbr1 count
# 174 ave. Artifacts profile, dn count
# 175 ave. DN profile, sox2 count
# 176 ave. DN profile, tbr1 count
# 177 ave. DN profile, dn count
# 178 ave. Adjacent profile, sox2 count
# 179 ave. Adjacent profile, tbr1 count
# 180 ave. Adjacent profile, dn count
# 181 ave. TBR1-LowDN profile, sox2 mean position
# 182 ave. TBR1-LowDN profile, tbr1 mean position
# 183 ave. TBR1-LowDN profile, dn mean position
# 184 ave. TBR1-HighDN profile, sox2 mean position
# 185 ave. TBR1-HighDN profile, tbr1 mean position
# 186 ave. TBR1-HighDN profile, dn mean position
# 187 ave. Surface profile, sox2 mean position
# 188 ave. Surface profile, tbr1 mean position
# 189 ave. Surface profile, dn mean position
# 190 ave. Artifacts profile, sox2 mean position
# 191 ave. Artifacts profile, tbr1 mean position
# 192 ave. Artifacts profile, dn mean position
# 193 ave. DN profile, sox2 mean position
# 194 ave. DN profile, tbr1 mean position
# 195 ave. DN profile, dn mean position
# 196 ave. Adjacent profile, sox2 mean position
# 197 ave. Adjacent profile, tbr1 mean position
# 198 ave. Adjacent profile, dn mean position
# 199 ave. TBR1-LowDN profile, sox2 profile stdev
# 200 ave. TBR1-LowDN profile, tbr1 profile stdev
# 201 ave. TBR1-LowDN profile, dn profile stdev
# 202 ave. TBR1-HighDN profile, sox2 profile stdev
# 203 ave. TBR1-HighDN profile, tbr1 profile stdev
# 204 ave. TBR1-HighDN profile, dn profile stdev
# 205 ave. Surface profile, sox2 profile stdev
# 206 ave. Surface profile, tbr1 profile stdev
# 207 ave. Surface profile, dn profile stdev
# 208 ave. Artifacts profile, sox2 profile stdev
# 209 ave. Artifacts profile, tbr1 profile stdev
# 210 ave. Artifacts profile, dn profile stdev
# 211 ave. DN profile, sox2 profile stdev
# 212 ave. DN profile, tbr1 profile stdev
# 213 ave. DN profile, dn profile stdev
# 214 ave. Adjacent profile, sox2 profile stdev
# 215 ave. Adjacent profile, tbr1 profile stdev
# 216 ave. Adjacent profile, dn profile stdev
# 217 organoid volume (mm3)
# 218 organoid equivalent diameter (mm)
# 219 organoid major axis (mm)
# 220 organoid minor axis (mm)
# 221 organoid axis ratio
# 222 ventricle count
# 223 ventricle volume mean (um3)
# 224 ventricle volume stdev (um3)
# 225 ventricle equivalent diameter mean (um)
# 226 ventricle equivalent diameter stdev (um)
# 227 ventricle major axis mean (um)
# 228 ventricle major axis stdev (um)
# 229 ventricle minor axis mean (um)
# 230 ventricle minor axis stdev (um)
# 231 ventricle axis ratio mean
# 232 ventricle axis ratio stdev
# 233 DN nbrhd, sox2 surface distance mean (um)
# 234 DN nbrhd, sox2 surface distance stdev (um)
# 235 DN nbrhd, tbr1 surface distance mean (um)
# 236 DN nbrhd, tbr1 surface distance stdev (um)
# 237 DN nbrhd, dn surface distance mean (um)
# 238 DN nbrhd, dn surface distance stdev (um)
# 239 SOX2 nbrhd, sox2 surface distance mean (um)
# 240 SOX2 nbrhd, sox2 surface distance stdev (um)
# 241 SOX2 nbrhd, tbr1 surface distance mean (um)
# 242 SOX2 nbrhd, tbr1 surface distance stdev (um)
# 243 SOX2 nbrhd, dn surface distance mean (um)
# 244 SOX2 nbrhd, dn surface distance stdev (um)
# 245 TBR1 nbrhd, sox2 surface distance mean (um)
# 246 TBR1 nbrhd, sox2 surface distance stdev (um)
# 247 TBR1 nbrhd, tbr1 surface distance mean (um)
# 248 TBR1 nbrhd, tbr1 surface distance stdev (um)
# 249 TBR1 nbrhd, dn surface distance mean (um)
# 250 TBR1 nbrhd, dn surface distance stdev (um)
# 251 DP nbrhd, sox2 surface distance mean (um)
# 252 DP nbrhd, sox2 surface distance stdev (um)
# 253 DP nbrhd, tbr1 surface distance mean (um)
# 254 DP nbrhd, tbr1 surface distance stdev (um)
# 255 DP nbrhd, dn surface distance mean (um)
# 256 DP nbrhd, dn surface distance stdev (um)
# 257 MidTBR1 nbrhd, sox2 surface distance mean (um)
# 258 MidTBR1 nbrhd, sox2 surface distance stdev (um)
# 259 MidTBR1 nbrhd, tbr1 surface distance mean (um)
# 260 MidTBR1 nbrhd, tbr1 surface distance stdev (um)
# 261 MidTBR1 nbrhd, dn surface distance mean (um)
# 262 MidTBR1 nbrhd, dn surface distance stdev (um)
# 263 MidSOX2 nbrhd, sox2 surface distance mean (um)
# 264 MidSOX2 nbrhd, sox2 surface distance stdev (um)
# 265 MidSOX2 nbrhd, tbr1 surface distance mean (um)
# 266 MidSOX2 nbrhd, tbr1 surface distance stdev (um)
# 267 MidSOX2 nbrhd, dn surface distance mean (um)
# 268 MidSOX2 nbrhd, dn surface distance stdev (um)
# 269 MidInter nbrhd, sox2 surface distance mean (um)
# 270 MidInter nbrhd, sox2 surface distance stdev (um)
# 271 MidInter nbrhd, tbr1 surface distance mean (um)
# 272 MidInter nbrhd, tbr1 surface distance stdev (um)
# 273 MidInter nbrhd, dn surface distance mean (um)
# 274 MidInter nbrhd, dn surface distance stdev (um)

# %%
scales = np.asarray(157 * ['cell'] + (217-157) * ['cyto'] + (275 - 217) * ['organoid'])
scales = pd.Series(scales, index=df_r.index)
len(scales)
# Out:
# 275

# %%
lut = dict(zip(scales.unique(), "rgb"))
lut
# Out:
# {'cell': 'r', 'cyto': 'g', 'organoid': 'b'}

# %%
row_colors = scales.map(lut)

# %%
sns.set(font_scale=0.6)
cg = sns.clustermap(df_r, 
                    method='ward', 
                    metric='euclidean',
                    cmap='coolwarm', 
                    row_colors=row_colors,
                    figsize=(50, 50), 
                    vmin=-1, 
                    vmax=1)
plt.savefig(os.path.join(working_dir, 'clustermap.pdf'), bbox_inches='tight')
plt.show()

# %%
cg.dendrogram_col.reordered_ind
# Out:
# [187,
#  7,
#  20,
#  199,
#  217,
#  218,
#  219,
#  3,
#  220,
#  84,
#  19,
#  201,
#  5,
#  136,
#  222,
#  2,
#  17,
#  144,
#  86,
#  221,
#  78,
#  149,
#  160,
#  205,
#  207,
#  129,
#  4,
#  169,
#  197,
#  8,
#  14,
#  223,
#  227,
#  225,
#  229,
#  226,
#  228,
#  224,
#  230,
#  194,
#  212,
#  186,
#  213,
#  126,
#  216,
#  183,
#  13,
#  189,
#  162,
#  181,
#  22,
#  139,
#  231,
#  182,
#  200,
#  170,
#  188,
#  109,
#  113,
#  112,
#  116,
#  110,
#  114,
#  107,
#  108,
#  249,
#  247,
#  261,
#  257,
#  259,
#  260,
#  209,
#  245,
#  241,
#  251,
#  253,
#  246,
#  252,
#  254,
#  242,
#  270,
#  272,
#  268,
#  274,
#  271,
#  269,
#  273,
#  264,
#  239,
#  240,
#  237,
#  263,
#  267,
#  234,
#  238,
#  258,
#  250,
#  248,
#  262,
#  265,
#  266,
#  82,
#  208,
#  243,
#  244,
#  235,
#  233,
#  236,
#  210,
#  97,
#  145,
#  151,
#  127,
#  133,
#  85,
#  142,
#  154,
#  27,
#  135,
#  143,
#  83,
#  25,
#  29,
#  98,
#  146,
#  176,
#  161,
#  180,
#  156,
#  165,
#  168,
#  177,
#  196,
#  130,
#  131,
#  23,
#  184,
#  166,
#  175,
#  95,
#  163,
#  193,
#  30,
#  99,
#  141,
#  89,
#  164,
#  256,
#  118,
#  120,
#  137,
#  255,
#  123,
#  121,
#  211,
#  80,
#  192,
#  104,
#  190,
#  191,
#  76,
#  81,
#  215,
#  138,
#  158,
#  171,
#  66,
#  38,
#  52,
#  64,
#  62,
#  72,
#  68,
#  36,
#  50,
#  42,
#  56,
#  32,
#  46,
#  34,
#  70,
#  40,
#  54,
#  58,
#  44,
#  48,
#  60,
#  122,
#  77,
#  6,
#  128,
#  15,
#  18,
#  125,
#  73,
#  79,
#  75,
#  16,
#  0,
#  12,
#  1,
#  152,
#  92,
#  167,
#  185,
#  179,
#  203,
#  232,
#  153,
#  65,
#  37,
#  51,
#  63,
#  35,
#  49,
#  59,
#  69,
#  61,
#  67,
#  71,
#  33,
#  47,
#  39,
#  53,
#  43,
#  57,
#  41,
#  55,
#  31,
#  45,
#  26,
#  132,
#  21,
#  157,
#  206,
#  9,
#  10,
#  124,
#  198,
#  202,
#  88,
#  101,
#  91,
#  147,
#  74,
#  214,
#  11,
#  117,
#  119,
#  93,
#  94,
#  103,
#  96,
#  105,
#  24,
#  148,
#  150,
#  90,
#  100,
#  195,
#  172,
#  173,
#  174,
#  87,
#  140,
#  28,
#  155,
#  102,
#  134,
#  178,
#  111,
#  115,
#  159,
#  106,
#  204]

# %%
# Save table
cluster_idx = cg.dendrogram_col.reordered_ind
sorted_features = np.asarray(features)[cluster_idx]
df_clustered = df_r.reindex(sorted_features)[sorted_features]
df_clustered.to_excel(os.path.join(working_dir, 'clustered_correlation_table.xlsx'))

# %% [markdown]
# Construct graph from correlations

# %%
from pyvis import network as net
import networkx as nx

# %%
rmin = 0.7

R_eye = R[cluster_idx][:, cluster_idx] - np.eye(len(R))
R_eye = np.abs(R_eye)
mask = (R_eye > rmin)
R_eye = R_eye * mask

plt.imshow(R_eye, clim=[0, 1])

# %%
rename = dict(zip(np.arange(len(R)).astype(str), features))
colors = {'cell': 'Red', 
          'cyto': 'Green', 
          'organoid': 'Blue'}
colors_map = dict(zip(df_imputed.index, [colors[s] for s in df_imputed['scales']]))

# %%
nxg = nx.from_numpy_matrix(R_eye)

# %%
g = net.Network(notebook=True, height='800px', width='800px')
g.from_nx(nxg)
for i, node in enumerate(g.nodes):
    feat = rename[g.nodes[i]['title']]
    g.nodes[i]['label'] = feat
    g.nodes[i]['color'] = colors_map[feat]
    
# len(g.nodes)
g.barnes_hut()
# g.show(os.path.join(working_dir, 'feature_correlation_graph.html'))
g.show('example.html')
# Out:
#         <iframe
#             width="800px"
#             height="800px"
#             src="example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Linear regression analysis

# %% [markdown]
# Select cyto and cell level features for these analyses

# %%
df_imputed['scales'] = scales
df_imputed.head()
# Out:
#                         20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                174.0
# DN nbrhd, tbr1 count                                                110.0
# DN nbrhd, dn count                                               257563.0
# SOX2 nbrhd, sox2 count                                           550868.0
# SOX2 nbrhd, tbr1 count                                             1296.0
#
#                         20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                 30.0
# DN nbrhd, tbr1 count                                                 37.0
# DN nbrhd, dn count                                               112764.0
# SOX2 nbrhd, sox2 count                                           362686.0
# SOX2 nbrhd, tbr1 count                                              435.0
#
#                         20190419_16_09_03_AA_org3_488LP13_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                162.0
# DN nbrhd, tbr1 count                                                 50.0
# DN nbrhd, dn count                                               135904.0
# SOX2 nbrhd, sox2 count                                           471401.0
# SOX2 nbrhd, tbr1 count                                             1003.0
#
#                         20190430_11_36_09_AA-4.30.19-org1_488LP12p5_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                189.0
# DN nbrhd, tbr1 count                                                 21.0
# DN nbrhd, dn count                                                83305.0
# SOX2 nbrhd, sox2 count                                           494048.0
# SOX2 nbrhd, tbr1 count                                              672.0
#
#                         20190430_15_06_10_AA-4.30.19-org3_488LP13_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                345.0
# DN nbrhd, tbr1 count                                                105.0
# DN nbrhd, dn count                                               296077.0
# SOX2 nbrhd, sox2 count                                           833321.0
# SOX2 nbrhd, tbr1 count                                             2094.0
#
#                         20190614_14_03_07_AA_ef23-1_488LP14_561LP120_642LP60  \
# input
# DN nbrhd, sox2 count                                                121.0
# DN nbrhd, tbr1 count                                                 63.0
# DN nbrhd, dn count                                                95223.0
# SOX2 nbrhd, sox2 count                                           218660.0
# SOX2 nbrhd, tbr1 count                                              838.0
#
#                         20190614_14_48_43_AA_ef23-2_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                207.0
# DN nbrhd, tbr1 count                                                171.0
# DN nbrhd, dn count                                               471900.0
# SOX2 nbrhd, sox2 count                                           634230.0
# SOX2 nbrhd, tbr1 count                                             2572.0
#
#                         20190614_15_40_09_AA_ef23-3_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                162.0
# DN nbrhd, tbr1 count                                                143.0
# DN nbrhd, dn count                                               556212.0
# SOX2 nbrhd, sox2 count                                           707343.0
# SOX2 nbrhd, tbr1 count                                             1652.0
#
#                         20190614_17_14_47_AA_ef23-4_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                145.0
# DN nbrhd, tbr1 count                                                106.0
# DN nbrhd, dn count                                               341938.0
# SOX2 nbrhd, sox2 count                                           462029.0
# SOX2 nbrhd, tbr1 count                                             1256.0
#
#                         20190614_17_55_05_AA_ef23-5_488LP15_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                103.0
# DN nbrhd, tbr1 count                                                 31.0
# DN nbrhd, dn count                                                92981.0
# SOX2 nbrhd, sox2 count                                           134363.0
# SOX2 nbrhd, tbr1 count                                              498.0
#
#                         20190614_18_12_44_AA_ef23-6_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                               1704.0
# DN nbrhd, tbr1 count                                                538.0
# DN nbrhd, dn count                                                79213.0
# SOX2 nbrhd, sox2 count                                           350636.0
# SOX2 nbrhd, tbr1 count                                             1715.0
#
#                         20190614_18_27_34_AA_ef23-7_488LP14_561LP120_642LP50  \
# input
# DN nbrhd, sox2 count                                                165.0
# DN nbrhd, tbr1 count                                                 68.0
# DN nbrhd, dn count                                                76304.0
# SOX2 nbrhd, sox2 count                                            85757.0
# SOX2 nbrhd, tbr1 count                                              686.0
#
#                        scales
# input
# DN nbrhd, sox2 count     cell
# DN nbrhd, tbr1 count     cell
# DN nbrhd, dn count       cell
# SOX2 nbrhd, sox2 count   cell
# SOX2 nbrhd, tbr1 count   cell

# %%
features
# Out:
# ['DN nbrhd, sox2 count',
#  'DN nbrhd, tbr1 count',
#  'DN nbrhd, dn count',
#  'SOX2 nbrhd, sox2 count',
#  'SOX2 nbrhd, tbr1 count',
#  'SOX2 nbrhd, dn count',
#  'TBR1 nbrhd, sox2 count',
#  'TBR1 nbrhd, tbr1 count',
#  'TBR1 nbrhd, dn count',
#  'DP nbrhd, sox2 count',
#  'DP nbrhd, tbr1 count',
#  'DP nbrhd, dn count',
#  'MidTBR1 nbrhd, sox2 count',
#  'MidTBR1 nbrhd, tbr1 count',
#  'MidTBR1 nbrhd, dn count',
#  'MidSOX2 nbrhd, sox2 count',
#  'MidSOX2 nbrhd, tbr1 count',
#  'MidSOX2 nbrhd, dn count',
#  'MidInter nbrhd, sox2 count',
#  'MidInter nbrhd, tbr1 count',
#  'MidInter nbrhd, dn count',
#  'DN nbrhd fraction',
#  'SOX2 nbrhd fraction',
#  'TBR1 nbrhd fraction',
#  'DP nbrhd fraction',
#  'MidTBR1 nbrhd fraction',
#  'MidSOX2 nbrhd fraction',
#  'MidInter nbrhd fraction',
#  'TBR1 / SOX2 ratio',
#  'MidTBR1 / MidSOX2 ratio',
#  'MidInter / DN ratio',
#  'DN nbrhd, eq diam mean',
#  'DN nbrhd, eq diam stdev',
#  'SOX2 nbrhd, eq diam mean',
#  'SOX2 nbrhd, eq diam stdev',
#  'TBR1 nbrhd, eq diam mean',
#  'TBR1 nbrhd, eq diam stdev',
#  'DP nbrhd, eq diam mean',
#  'DP nbrhd, eq diam stdev',
#  'MidTBR1 nbrhd, eq diam mean',
#  'MidTBR1 nbrhd, eq diam stdev',
#  'MidSOX2 nbrhd, eq diam mean',
#  'MidSOX2 nbrhd, eq diam stdev',
#  'MidInter nbrhd, eq diam mean',
#  'MidInter nbrhd, eq diam stdev',
#  'DN nbrhd, major axis mean',
#  'DN nbrhd, major axis stdev',
#  'SOX2 nbrhd, major axis mean',
#  'SOX2 nbrhd, major axis stdev',
#  'TBR1 nbrhd, major axis mean',
#  'TBR1 nbrhd, major axis stdev',
#  'DP nbrhd, major axis mean',
#  'DP nbrhd, major axis stdev',
#  'MidTBR1 nbrhd, major axis mean',
#  'MidTBR1 nbrhd, major axis stdev',
#  'MidSOX2 nbrhd, major axis mean',
#  'MidSOX2 nbrhd, major axis stdev',
#  'MidInter nbrhd, major axis mean',
#  'MidInter nbrhd, major axis stdev',
#  'DN nbrhd, axis ratio mean',
#  'DN nbrhd, axis ratio stdev',
#  'SOX2 nbrhd, axis ratio mean',
#  'SOX2 nbrhd, axis ratio stdev',
#  'TBR1 nbrhd, axis ratio mean',
#  'TBR1 nbrhd, axis ratio stdev',
#  'DP nbrhd, axis ratio mean',
#  'DP nbrhd, axis ratio stdev',
#  'MidTBR1 nbrhd, axis ratio mean',
#  'MidTBR1 nbrhd, axis ratio stdev',
#  'MidSOX2 nbrhd, axis ratio mean',
#  'MidSOX2 nbrhd, axis ratio stdev',
#  'MidInter nbrhd, axis ratio mean',
#  'MidInter nbrhd, axis ratio stdev',
#  'DN nbrhd, sox2 proximity to SOX2 mean',
#  'DN nbrhd, sox2 proximity to SOX2 stdev',
#  'DN nbrhd, sox2 proximity to TBR1 mean',
#  'DN nbrhd, sox2 proximity to TBR1 stdev',
#  'DN nbrhd, tbr1 proximity to SOX2 mean',
#  'DN nbrhd, tbr1 proximity to SOX2 stdev',
#  'DN nbrhd, tbr1 proximity to TBR1 mean',
#  'DN nbrhd, tbr1 proximity to TBR1 stdev',
#  'DN nbrhd, dn proximity to SOX2 mean',
#  'DN nbrhd, dn proximity to SOX2 stdev',
#  'DN nbrhd, dn proximity to TBR1 mean',
#  'DN nbrhd, dn proximity to TBR1 stdev',
#  'SOX2 nbrhd, sox2 proximity to SOX2 mean',
#  'SOX2 nbrhd, sox2 proximity to SOX2 stdev',
#  'SOX2 nbrhd, sox2 proximity to TBR1 mean',
#  'SOX2 nbrhd, sox2 proximity to TBR1 stdev',
#  'SOX2 nbrhd, tbr1 proximity to SOX2 mean',
#  'SOX2 nbrhd, tbr1 proximity to SOX2 stdev',
#  'SOX2 nbrhd, tbr1 proximity to TBR1 mean',
#  'SOX2 nbrhd, tbr1 proximity to TBR1 stdev',
#  'SOX2 nbrhd, dn proximity to SOX2 mean',
#  'SOX2 nbrhd, dn proximity to SOX2 stdev',
#  'SOX2 nbrhd, dn proximity to TBR1 mean',
#  'SOX2 nbrhd, dn proximity to TBR1 stdev',
#  'TBR1 nbrhd, sox2 proximity to SOX2 mean',
#  'TBR1 nbrhd, sox2 proximity to SOX2 stdev',
#  'TBR1 nbrhd, sox2 proximity to TBR1 mean',
#  'TBR1 nbrhd, sox2 proximity to TBR1 stdev',
#  'TBR1 nbrhd, tbr1 proximity to SOX2 mean',
#  'TBR1 nbrhd, tbr1 proximity to SOX2 stdev',
#  'TBR1 nbrhd, tbr1 proximity to TBR1 mean',
#  'TBR1 nbrhd, tbr1 proximity to TBR1 stdev',
#  'TBR1 nbrhd, dn proximity to SOX2 mean',
#  'TBR1 nbrhd, dn proximity to SOX2 stdev',
#  'TBR1 nbrhd, dn proximity to TBR1 mean',
#  'TBR1 nbrhd, dn proximity to TBR1 stdev',
#  'DP nbrhd, sox2 proximity to SOX2 mean',
#  'DP nbrhd, sox2 proximity to SOX2 stdev',
#  'DP nbrhd, sox2 proximity to TBR1 mean',
#  'DP nbrhd, sox2 proximity to TBR1 stdev',
#  'DP nbrhd, tbr1 proximity to SOX2 mean',
#  'DP nbrhd, tbr1 proximity to SOX2 stdev',
#  'DP nbrhd, tbr1 proximity to TBR1 mean',
#  'DP nbrhd, tbr1 proximity to TBR1 stdev',
#  'DP nbrhd, dn proximity to SOX2 mean',
#  'DP nbrhd, dn proximity to SOX2 stdev',
#  'DP nbrhd, dn proximity to TBR1 mean',
#  'DP nbrhd, dn proximity to TBR1 stdev',
#  'MidTBR1 nbrhd, sox2 proximity to SOX2 mean',
#  'MidTBR1 nbrhd, sox2 proximity to SOX2 stdev',
#  'MidTBR1 nbrhd, sox2 proximity to TBR1 mean',
#  'MidTBR1 nbrhd, sox2 proximity to TBR1 stdev',
#  'MidTBR1 nbrhd, tbr1 proximity to SOX2 mean',
#  'MidTBR1 nbrhd, tbr1 proximity to SOX2 stdev',
#  'MidTBR1 nbrhd, tbr1 proximity to TBR1 mean',
#  'MidTBR1 nbrhd, tbr1 proximity to TBR1 stdev',
#  'MidTBR1 nbrhd, dn proximity to SOX2 mean',
#  'MidTBR1 nbrhd, dn proximity to SOX2 stdev',
#  'MidTBR1 nbrhd, dn proximity to TBR1 mean',
#  'MidTBR1 nbrhd, dn proximity to TBR1 stdev',
#  'MidSOX2 nbrhd, sox2 proximity to SOX2 mean',
#  'MidSOX2 nbrhd, sox2 proximity to SOX2 stdev',
#  'MidSOX2 nbrhd, sox2 proximity to TBR1 mean',
#  'MidSOX2 nbrhd, sox2 proximity to TBR1 stdev',
#  'MidSOX2 nbrhd, tbr1 proximity to SOX2 mean',
#  'MidSOX2 nbrhd, tbr1 proximity to SOX2 stdev',
#  'MidSOX2 nbrhd, tbr1 proximity to TBR1 mean',
#  'MidSOX2 nbrhd, tbr1 proximity to TBR1 stdev',
#  'MidSOX2 nbrhd, dn proximity to SOX2 mean',
#  'MidSOX2 nbrhd, dn proximity to SOX2 stdev',
#  'MidSOX2 nbrhd, dn proximity to TBR1 mean',
#  'MidSOX2 nbrhd, dn proximity to TBR1 stdev',
#  'MidInter nbrhd, sox2 proximity to SOX2 mean',
#  'MidInter nbrhd, sox2 proximity to SOX2 stdev',
#  'MidInter nbrhd, sox2 proximity to TBR1 mean',
#  'MidInter nbrhd, sox2 proximity to TBR1 stdev',
#  'MidInter nbrhd, tbr1 proximity to SOX2 mean',
#  'MidInter nbrhd, tbr1 proximity to SOX2 stdev',
#  'MidInter nbrhd, tbr1 proximity to TBR1 mean',
#  'MidInter nbrhd, tbr1 proximity to TBR1 stdev',
#  'MidInter nbrhd, dn proximity to SOX2 mean',
#  'MidInter nbrhd, dn proximity to SOX2 stdev',
#  'MidInter nbrhd, dn proximity to TBR1 mean',
#  'MidInter nbrhd, dn proximity to TBR1 stdev',
#  'TBR1-LowDN cytoarchitecture fraction',
#  'TBR1-HighDN cytoarchitecture fraction',
#  'Surface cytoarchitecture fraction',
#  'Artifacts cytoarchitecture fraction',
#  'DN cytoarchitecture fraction',
#  'Adjacent cytoarchitecture fraction',
#  'ave. TBR1-LowDN profile, sox2 count',
#  'ave. TBR1-LowDN profile, tbr1 count',
#  'ave. TBR1-LowDN profile, dn count',
#  'ave. TBR1-HighDN profile, sox2 count',
#  'ave. TBR1-HighDN profile, tbr1 count',
#  'ave. TBR1-HighDN profile, dn count',
#  'ave. Surface profile, sox2 count',
#  'ave. Surface profile, tbr1 count',
#  'ave. Surface profile, dn count',
#  'ave. Artifacts profile, sox2 count',
#  'ave. Artifacts profile, tbr1 count',
#  'ave. Artifacts profile, dn count',
#  'ave. DN profile, sox2 count',
#  'ave. DN profile, tbr1 count',
#  'ave. DN profile, dn count',
#  'ave. Adjacent profile, sox2 count',
#  'ave. Adjacent profile, tbr1 count',
#  'ave. Adjacent profile, dn count',
#  'ave. TBR1-LowDN profile, sox2 mean position',
#  'ave. TBR1-LowDN profile, tbr1 mean position',
#  'ave. TBR1-LowDN profile, dn mean position',
#  'ave. TBR1-HighDN profile, sox2 mean position',
#  'ave. TBR1-HighDN profile, tbr1 mean position',
#  'ave. TBR1-HighDN profile, dn mean position',
#  'ave. Surface profile, sox2 mean position',
#  'ave. Surface profile, tbr1 mean position',
#  'ave. Surface profile, dn mean position',
#  'ave. Artifacts profile, sox2 mean position',
#  'ave. Artifacts profile, tbr1 mean position',
#  'ave. Artifacts profile, dn mean position',
#  'ave. DN profile, sox2 mean position',
#  'ave. DN profile, tbr1 mean position',
#  'ave. DN profile, dn mean position',
#  'ave. Adjacent profile, sox2 mean position',
#  'ave. Adjacent profile, tbr1 mean position',
#  'ave. Adjacent profile, dn mean position',
#  'ave. TBR1-LowDN profile, sox2 profile stdev',
#  'ave. TBR1-LowDN profile, tbr1 profile stdev',
#  'ave. TBR1-LowDN profile, dn profile stdev',
#  'ave. TBR1-HighDN profile, sox2 profile stdev',
#  'ave. TBR1-HighDN profile, tbr1 profile stdev',
#  'ave. TBR1-HighDN profile, dn profile stdev',
#  'ave. Surface profile, sox2 profile stdev',
#  'ave. Surface profile, tbr1 profile stdev',
#  'ave. Surface profile, dn profile stdev',
#  'ave. Artifacts profile, sox2 profile stdev',
#  'ave. Artifacts profile, tbr1 profile stdev',
#  'ave. Artifacts profile, dn profile stdev',
#  'ave. DN profile, sox2 profile stdev',
#  'ave. DN profile, tbr1 profile stdev',
#  'ave. DN profile, dn profile stdev',
#  'ave. Adjacent profile, sox2 profile stdev',
#  'ave. Adjacent profile, tbr1 profile stdev',
#  'ave. Adjacent profile, dn profile stdev',
#  'organoid volume (mm3)',
#  'organoid equivalent diameter (mm)',
#  'organoid major axis (mm)',
#  'organoid minor axis (mm)',
#  'organoid axis ratio',
#  'ventricle count',
#  'ventricle volume mean (um3)',
#  'ventricle volume stdev (um3)',
#  'ventricle equivalent diameter mean (um)',
#  'ventricle equivalent diameter stdev (um)',
#  'ventricle major axis mean (um)',
#  'ventricle major axis stdev (um)',
#  'ventricle minor axis mean (um)',
#  'ventricle minor axis stdev (um)',
#  'ventricle axis ratio mean',
#  'ventricle axis ratio stdev',
#  'DN nbrhd, sox2 surface distance mean (um)',
#  'DN nbrhd, sox2 surface distance stdev (um)',
#  'DN nbrhd, tbr1 surface distance mean (um)',
#  'DN nbrhd, tbr1 surface distance stdev (um)',
#  'DN nbrhd, dn surface distance mean (um)',
#  'DN nbrhd, dn surface distance stdev (um)',
#  'SOX2 nbrhd, sox2 surface distance mean (um)',
#  'SOX2 nbrhd, sox2 surface distance stdev (um)',
#  'SOX2 nbrhd, tbr1 surface distance mean (um)',
#  'SOX2 nbrhd, tbr1 surface distance stdev (um)',
#  'SOX2 nbrhd, dn surface distance mean (um)',
#  'SOX2 nbrhd, dn surface distance stdev (um)',
#  'TBR1 nbrhd, sox2 surface distance mean (um)',
#  'TBR1 nbrhd, sox2 surface distance stdev (um)',
#  'TBR1 nbrhd, tbr1 surface distance mean (um)',
#  'TBR1 nbrhd, tbr1 surface distance stdev (um)',
#  'TBR1 nbrhd, dn surface distance mean (um)',
#  'TBR1 nbrhd, dn surface distance stdev (um)',
#  'DP nbrhd, sox2 surface distance mean (um)',
#  'DP nbrhd, sox2 surface distance stdev (um)',
#  'DP nbrhd, tbr1 surface distance mean (um)',
#  'DP nbrhd, tbr1 surface distance stdev (um)',
#  'DP nbrhd, dn surface distance mean (um)',
#  'DP nbrhd, dn surface distance stdev (um)',
#  'MidTBR1 nbrhd, sox2 surface distance mean (um)',
#  'MidTBR1 nbrhd, sox2 surface distance stdev (um)',
#  'MidTBR1 nbrhd, tbr1 surface distance mean (um)',
#  'MidTBR1 nbrhd, tbr1 surface distance stdev (um)',
#  'MidTBR1 nbrhd, dn surface distance mean (um)',
#  'MidTBR1 nbrhd, dn surface distance stdev (um)',
#  'MidSOX2 nbrhd, sox2 surface distance mean (um)',
#  'MidSOX2 nbrhd, sox2 surface distance stdev (um)',
#  'MidSOX2 nbrhd, tbr1 surface distance mean (um)',
#  'MidSOX2 nbrhd, tbr1 surface distance stdev (um)',
#  'MidSOX2 nbrhd, dn surface distance mean (um)',
#  'MidSOX2 nbrhd, dn surface distance stdev (um)',
#  'MidInter nbrhd, sox2 surface distance mean (um)',
#  'MidInter nbrhd, sox2 surface distance stdev (um)',
#  'MidInter nbrhd, tbr1 surface distance mean (um)',
#  'MidInter nbrhd, tbr1 surface distance stdev (um)',
#  'MidInter nbrhd, dn surface distance mean (um)',
#  'MidInter nbrhd, dn surface distance stdev (um)']

# %% [markdown]
# Organoid volume linear regression

# %%
import statsmodels.api as sm

# %%
# Based on counts

keep = [
 'DN nbrhd, dn count',
 'SOX2 nbrhd, sox2 count',
 'TBR1 nbrhd, tbr1 count',
 'MidTBR1 nbrhd, dn count',
 'MidSOX2 nbrhd, dn count',
 'MidInter nbrhd, dn count'
]

df_filt = df_imputed.loc[keep]
X = df_filt.drop(columns='scales').T

print('organoid volume')
y = df_imputed.loc['organoid volume (mm3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle volume')
y = df_imputed.loc['ventricle volume mean (um3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle count')
y = df_imputed.loc['ventricle count'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())
# Out:
# organoid volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              1536.
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    2.75e-09
# Time:                        10:45:13   Log-Likelihood:                          14.551
# No. Observations:                  12   AIC:                                     -17.10
# Df Residuals:                       6   BIC:                                     -14.19
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# DN nbrhd, dn count        3.606e-06   1.02e-06      3.520      0.013     1.1e-06    6.11e-06
# SOX2 nbrhd, sox2 count    1.407e-06    8.4e-07      1.676      0.145   -6.48e-07    3.46e-06
# TBR1 nbrhd, tbr1 count    2.131e-06   2.71e-06      0.787      0.461   -4.49e-06    8.75e-06
# MidTBR1 nbrhd, dn count  -2.899e-06   1.69e-06     -1.715      0.137   -7.04e-06    1.24e-06
# MidSOX2 nbrhd, dn count  -9.268e-07   1.76e-06     -0.526      0.618   -5.24e-06    3.38e-06
# MidInter nbrhd, dn count  1.146e-05   5.46e-06      2.100      0.081    -1.9e-06    2.48e-05
# ==============================================================================
# Omnibus:                        0.657   Durbin-Watson:                   1.042
# Prob(Omnibus):                  0.720   Jarque-Bera (JB):                0.626
# Skew:                          -0.418   Prob(JB):                        0.731
# Kurtosis:                       2.257   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.995
# Model:                            OLS   Adj. R-squared (uncentered):              0.990
# Method:                 Least Squares   F-statistic:                              197.1
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    1.28e-06
# Time:                        10:45:13   Log-Likelihood:                         -165.33
# No. Observations:                  12   AIC:                                      342.7
# Df Residuals:                       6   BIC:                                      345.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# DN nbrhd, dn count           4.9216      3.316      1.484      0.188      -3.192      13.035
# SOX2 nbrhd, sox2 count       0.2789      2.719      0.103      0.922      -6.373       6.931
# TBR1 nbrhd, tbr1 count      42.9083      8.762      4.897      0.003      21.467      64.349
# MidTBR1 nbrhd, dn count     13.2602      5.473      2.423      0.052      -0.132      26.652
# MidSOX2 nbrhd, dn count    -12.8317      5.699     -2.251      0.065     -26.778       1.114
# MidInter nbrhd, dn count   -42.1201     17.674     -2.383      0.055     -85.367       1.127
# ==============================================================================
# Omnibus:                        7.698   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                3.486
# Skew:                           1.084   Prob(JB):                        0.175
# Kurtosis:                       4.506   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle count
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.978
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              44.74
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    0.000101
# Time:                        10:45:14   Log-Likelihood:                         -51.009
# No. Observations:                  12   AIC:                                      114.0
# Df Residuals:                       6   BIC:                                      116.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# DN nbrhd, dn count          -0.0002      0.000     -0.695      0.513      -0.001       0.000
# SOX2 nbrhd, sox2 count      -0.0002      0.000     -0.955      0.377      -0.001       0.000
# TBR1 nbrhd, tbr1 count      -0.0005      0.001     -0.789      0.460      -0.002       0.001
# MidTBR1 nbrhd, dn count   3.233e-05      0.000      0.081      0.938      -0.001       0.001
# MidSOX2 nbrhd, dn count      0.0007      0.000      1.748      0.131      -0.000       0.002
# MidInter nbrhd, dn count     0.0014      0.001      1.103      0.312      -0.002       0.005
# ==============================================================================
# Omnibus:                        5.783   Durbin-Watson:                   1.296
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                2.725
# Skew:                           1.133   Prob(JB):                        0.256
# Kurtosis:                       3.563   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
keep = [
 'DN nbrhd fraction',
 'SOX2 nbrhd fraction',
 'TBR1 nbrhd fraction',
 'MidTBR1 nbrhd fraction',
 'MidSOX2 nbrhd fraction',
 'MidInter nbrhd fraction'
]

df_filt = df_imputed.loc[keep]
X = df_filt.drop(columns='scales').T

print('organoid volume')
y = df_imputed.loc['organoid volume (mm3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle volume')
y = df_imputed.loc['ventricle volume mean (um3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle count')
y = df_imputed.loc['ventricle count'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())
# Out:
# organoid volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.969
# Method:                 Least Squares   F-statistic:                              63.99
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    3.56e-05
# Time:                        10:46:02   Log-Likelihood:                         -4.4286
# No. Observations:                  12   AIC:                                      20.86
# Df Residuals:                       6   BIC:                                      23.77
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# DN nbrhd fraction          13.4265      3.685      3.644      0.011       4.411      22.442
# SOX2 nbrhd fraction        12.3133      3.985      3.090      0.021       2.564      22.063
# TBR1 nbrhd fraction        21.2012     14.649      1.447      0.198     -14.644      57.046
# MidTBR1 nbrhd fraction     -8.1551      4.659     -1.751      0.131     -19.554       3.244
# MidSOX2 nbrhd fraction    -13.3425      8.604     -1.551      0.172     -34.396       7.711
# MidInter nbrhd fraction   -25.1179     15.793     -1.590      0.163     -63.761      13.525
# ==============================================================================
# Omnibus:                        1.163   Durbin-Watson:                   1.334
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                0.850
# Skew:                          -0.581   Prob(JB):                        0.654
# Kurtosis:                       2.406   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.945
# Method:                 Least Squares   F-statistic:                              35.45
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    0.000198
# Time:                        10:46:02   Log-Likelihood:                         -175.49
# No. Observations:                  12   AIC:                                      363.0
# Df Residuals:                       6   BIC:                                      365.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# DN nbrhd fraction        8.402e+06   5.72e+06      1.470      0.192   -5.59e+06    2.24e+07
# SOX2 nbrhd fraction      1.117e+07   6.18e+06      1.807      0.121   -3.96e+06    2.63e+07
# TBR1 nbrhd fraction      7.431e+07   2.27e+07      3.269      0.017    1.87e+07     1.3e+08
# MidTBR1 nbrhd fraction  -2.614e+06   7.23e+06     -0.362      0.730   -2.03e+07    1.51e+07
# MidSOX2 nbrhd fraction  -2.824e+07   1.33e+07     -2.116      0.079   -6.09e+07    4.42e+06
# MidInter nbrhd fraction  -5.89e+07   2.45e+07     -2.404      0.053   -1.19e+08    1.06e+06
# ==============================================================================
# Omnibus:                        0.399   Durbin-Watson:                   1.106
# Prob(Omnibus):                  0.819   Jarque-Bera (JB):                0.441
# Skew:                          -0.334   Prob(JB):                        0.802
# Kurtosis:                       2.339   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle count
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.989
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              93.08
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    1.18e-05
# Time:                        10:46:03   Log-Likelihood:                         -46.681
# No. Observations:                  12   AIC:                                      105.4
# Df Residuals:                       6   BIC:                                      108.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# DN nbrhd fraction          97.7209    124.610      0.784      0.463    -207.189     402.631
# SOX2 nbrhd fraction       371.4759    134.757      2.757      0.033      41.739     701.213
# TBR1 nbrhd fraction      -451.0126    495.427     -0.910      0.398   -1663.278     761.253
# MidTBR1 nbrhd fraction      0.6255    157.557      0.004      0.997    -384.902     386.153
# MidSOX2 nbrhd fraction    455.2760    290.988      1.565      0.169    -256.745    1167.297
# MidInter nbrhd fraction  -203.6534    534.102     -0.381      0.716   -1510.555    1103.248
# ==============================================================================
# Omnibus:                       11.229   Durbin-Watson:                   1.521
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                6.110
# Skew:                          -1.439   Prob(JB):                       0.0471
# Kurtosis:                       4.985   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
keep = [
    'TBR1-LowDN cytoarchitecture fraction',
    'TBR1-HighDN cytoarchitecture fraction',
    'Surface cytoarchitecture fraction',
    'DN cytoarchitecture fraction',
    'Adjacent cytoarchitecture fraction',
]

df_filt = df_imputed.loc[keep]
X = df_filt.drop(columns='scales').T

print('organoid volume')
y = df_imputed.loc['organoid volume (mm3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 3], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle volume')
y = df_imputed.loc['ventricle volume mean (um3)'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 4], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())

print('ventricle count')
y = df_imputed.loc['ventricle count'].drop('scales').astype(np.float64)[:, np.newaxis]

plt.figure()
plt.scatter(X.values[:, 0], y.ravel())
plt.show()

model = sm.OLS(y, X).fit()
display(model.summary())
# Out:
# organoid volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.978
# Model:                            OLS   Adj. R-squared (uncentered):              0.963
# Method:                 Least Squares   F-statistic:                              62.85
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    1.16e-05
# Time:                        10:58:06   Log-Likelihood:                         -6.5168
# No. Observations:                  12   AIC:                                      23.03
# Df Residuals:                       7   BIC:                                      25.46
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# TBR1-LowDN cytoarchitecture fraction     34.3944      5.737      5.995      0.001      20.829      47.960
# TBR1-HighDN cytoarchitecture fraction     2.2278      5.448      0.409      0.695     -10.655      15.111
# Surface cytoarchitecture fraction        -7.1833      3.076     -2.335      0.052     -14.457       0.091
# DN cytoarchitecture fraction            -12.1721      3.123     -3.898      0.006     -19.557      -4.788
# Adjacent cytoarchitecture fraction        5.6283      1.715      3.282      0.013       1.573       9.684
# ==============================================================================
# Omnibus:                        0.337   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.845   Jarque-Bera (JB):                0.463
# Skew:                          -0.176   Prob(JB):                        0.793
# Kurtosis:                       2.104   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle volume
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.886
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              10.90
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                     0.00336
# Time:                        10:58:07   Log-Likelihood:                         -184.02
# No. Observations:                  12   AIC:                                      378.0
# Df Residuals:                       7   BIC:                                      380.5
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# TBR1-LowDN cytoarchitecture fraction   8.716e+06   1.52e+07      0.572      0.585   -2.73e+07    4.47e+07
# TBR1-HighDN cytoarchitecture fraction  1.993e+07   1.45e+07      1.378      0.211   -1.43e+07    5.41e+07
# Surface cytoarchitecture fraction     -4.295e+04   8.17e+06     -0.005      0.996   -1.94e+07    1.93e+07
# DN cytoarchitecture fraction          -1.711e+07   8.29e+06     -2.063      0.078   -3.67e+07     2.5e+06
# Adjacent cytoarchitecture fraction      4.97e+06   4.55e+06      1.091      0.311    -5.8e+06    1.57e+07
# ==============================================================================
# Omnibus:                        2.151   Durbin-Watson:                   2.347
# Prob(Omnibus):                  0.341   Jarque-Bera (JB):                1.321
# Skew:                           0.786   Prob(JB):                        0.517
# Kurtosis:                       2.589   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ventricle count
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.994
# Model:                            OLS   Adj. R-squared (uncentered):              0.989
# Method:                 Least Squares   F-statistic:                              219.4
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):                    1.56e-07
# Time:                        10:58:07   Log-Likelihood:                         -43.582
# No. Observations:                  12   AIC:                                      97.16
# Df Residuals:                       7   BIC:                                      99.59
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# TBR1-LowDN cytoarchitecture fraction    709.8201    125.923      5.637      0.001     412.060    1007.580
# TBR1-HighDN cytoarchitecture fraction   -34.9170    119.588     -0.292      0.779    -317.698     247.864
# Surface cytoarchitecture fraction      -318.4396     67.523     -4.716      0.002    -478.107    -158.772
# DN cytoarchitecture fraction             21.5426     68.549      0.314      0.762    -140.550     183.635
# Adjacent cytoarchitecture fraction      311.5232     37.644      8.275      0.000     222.508     400.538
# ==============================================================================
# Omnibus:                        2.394   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.302   Jarque-Bera (JB):                1.245
# Skew:                          -0.784   Prob(JB):                        0.537
# Kurtosis:                       2.823   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.scatterplot(x='organoid volume (mm3)', y='ventricle count', data=df.T)

# %%
df_imputed.T
# Out:
# input                                              DN nbrhd, sox2 count  \
# 20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60                  174
# 20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60                   30
# 20190419_16_09_03_AA_org3_488LP13_561LP120_642LP60                  162
# 20190430_11_36_09_AA-4.30.19-org1_488LP12p5_561...                  189
# 20190430_15_06_10_AA-4.30.19-org3_488LP13_561LP...                  345
# 20190614_14_03_07_AA_ef23-1_488LP14_561LP120_64...                  121
# 20190614_14_48_43_AA_ef23-2_488LP14_561LP120_64...                  207
# 20190614_15_40_09_AA_ef23-3_488LP14_561LP120_64...                  162
# 20190614_17_14_47_AA_ef23-4_488LP14_561LP120_64...                  145
# 20190614_17_55_05_AA_ef23-5_488LP15_561LP120_64...                  103
# 20190614_18_12_44_AA_ef23-6_488LP14_561LP120_64...                 1704
# 20190614_18_27_34_AA_ef23-7_488LP14_561LP120_64...                  165
# scales                                                             cell
#
# input                                              DN nbrhd, tbr1 count  \
# 20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60                  110
# 20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60                   37
# 20190419_16_09_03_AA_org3_488LP13_561LP120_642LP60                   50
# 20190430_11_36_09_AA-4.30.19-org1_488LP12p5_561...                   21
# 20190430_15_06_10_AA-4.30.19-org3_488LP13_561LP...                  105
# 20190614_14_03_07_AA_ef23-1_488LP14_561LP120_64...                   63
# 20190614_14_48_43_AA_ef23-2_488LP14_561LP120_64...                  171
# 20190614_15_40_09_AA_ef23-3_488LP14_561LP120_64...                  143
# 20190614_17_14_47_AA_ef23-4_488LP14_561LP120_64...                  106
# 20190614_17_55_05_AA_ef23-5_488LP15_561LP120_64...                   31
# 20190614_18_12_44_AA_ef23-6_488LP14_561LP120_64...                  538
# 20190614_18_27_34_AA_ef23-7_488LP14_561LP120_64...                   68
# scales                                                             cell
#
# input                                              DN nbrhd, dn count  \
# 20190419_14_35_07_AA_org1_488LP13_561LP120_642LP60             257563
# 20190419_15_50_16_AA_org2_488LP13_561LP120_642LP60             112764
