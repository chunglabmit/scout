# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scout import io
from scout.cyto import smooth_segmentation, load_mesh
from scout.utils import read_voxel_size, read_csv
from skimage.measure import label
from skimage.transform import resize

# %%
working_dir = '/data/datasets/organoid_phenotyping/analysis/d35_vs_d60/Lancaster_d35/20190614_14_03_07_AA_ef23-1_488LP14_561LP120_642LP60/'

os.listdir(os.path.join(working_dir, 'dataset'))
# Out:
# ['syto.zarr',
#  'Ex0_hist.csv',
#  'Ex2_hist.csv',
#  'nuclei_binary.zarr',
#  'nuclei_probability.zarr',
#  'nuclei_fluorescence',
#  'segment_ventricles.tif',
#  'Ex2_rescaled',
#  'nuclei_morphologies.csv',
#  'syto_down6x',
#  'Ex_1_Em_1_stitched',
#  'syto_down6x.tif',
#  'niche_labels.npy',
#  'Ex_0_Em_0_stitched',
#  'Ex1_hist.csv',
#  'Ex_2_Em_2_stitched',
#  'cyto_profiles.npy',
#  'nuclei_foreground.zarr',
#  'celltype_names.csv',
#  'centroids.npy',
#  'nuclei_gating.npy',
#  'cyto_profiles_sample.npy',
#  'sox2.zarr',
#  'niche_names.csv',
#  'voxel_size.csv',
#  'mesh_ventricles.pkl',
#  'tbr1.zarr',
#  'niche_proximities.npy',
#  'Ex0_rescaled',
#  'segment_foreground.tif',
#  'cyto_sample_index.npy',
#  'Ex1_rescaled',
#  'centroids_um.npy']

# %% [markdown]
# ## Compute connected components labeling

# %% [markdown]
# Load the ventricle segmentation

# %%
seg = io.imread(os.path.join(working_dir, 'dataset/segment_ventricles.tif'))
syto = io.imread(os.path.join(working_dir, 'dataset/syto_down6x.tif'))

plt.figure()
plt.imshow(syto[420])
plt.imshow(seg[420], alpha=0.5)
plt.axis('off')
plt.show()

# %%
seg_smoothed = smooth_segmentation(seg, sigma=2) > 0.5

plt.figure()
plt.imshow(syto[420])
plt.imshow(seg_smoothed[420], alpha=0.5)
plt.axis('off')
plt.show()

# %% [markdown]
# Resize based on voxel size

# %%
downsample_factor = np.array([1, 6, 6])

voxel_orig = read_voxel_size(os.path.join(working_dir, 'dataset/voxel_size.csv'))
print(f'Original voxel size: {voxel_orig}')

voxel_down = tuple(voxel_orig * downsample_factor)
print(f'Downsampled voxel size: {voxel_down}')

voxel_isotropic = tuple(max(voxel_down) * np.ones(len(voxel_down)))
print(f'Isotropic voxel size: {voxel_isotropic}')
# Out:
# Original voxel size: (2.0, 0.651, 0.651)
# Downsampled voxel size: (2.0, 3.906, 3.906)
# Isotropic voxel size: (3.906, 3.906, 3.906)

# %%
factors = np.asarray(voxel_isotropic) / np.asarray(voxel_down)
shape_isotropic = tuple([int(s / f) for s, f in zip(seg_smoothed.shape, factors)])
foreground = resize(seg_smoothed, output_shape=shape_isotropic, order=0, preserve_range=True)

# %%
foreground = foreground > 0

# %%
plt.figure()
plt.imshow(foreground[210])
plt.axis('off')
plt.show()

# %% [markdown]
# Label ventricle segmentation

# %%
labels = label(foreground)
labels.shape, f'Found {labels.max()} ventricles'
# Out:
# ((614, 924, 924), 'Found 84 ventricles')

# %%
for z in range(0, labels.shape[0], 50):
    plt.figure()
    plt.imshow(labels[z], clim=[0, 1])
    plt.title(z)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Compute morphological features

# %%
from skimage.measure import regionprops

# %%
regions = regionprops(labels)

# %%
volumes_pixels = np.asarray([region.area for region in regions])
eq_diams_pixels = np.asarray([region.equivalent_diameter for region in regions])
major_axes_pixels = np.asarray([region.major_axis_length for region in regions])
minor_axes_pixels = np.asarray([region.minor_axis_length for region in regions])

volumes_um3 = volumes_pixels * np.asarray(voxel_isotropic).prod()
eq_diams_um = eq_diams_pixels * voxel_isotropic[0]
major_axes_um = major_axes_pixels * voxel_isotropic[0]
minor_axes_um = minor_axes_pixels * voxel_isotropic[0]
axis_ratios = major_axes_pixels / np.clip(minor_axes_pixels, 1, None)

# %%
plt.plot(eq_diams_um, axis_ratios, '.')
plt.xlabel('Eq diam')
plt.ylabel('Axis ratio')
plt.show()

# %% [markdown]
# ## Compute cytoarchitecture frequencies

# %% [markdown]
# Get cytoarchitecture labels and mesh vertices

# %%
cyto_labels = np.load(os.path.join(working_dir, 'cyto_labels.npy'))
mesh = load_mesh(os.path.join(working_dir, 'dataset/mesh_ventricles.pkl'))

# %%
verts = mesh['verts']
verts.max(axis=0)
# Out:
# array([1818.3433, 2994.0815, 2925.7935], dtype=float32)

# %%
verts
# Out:
# array([[  35.36984, 1523.34   , 1031.184  ],
#        [  36.     , 1523.34   , 1029.1964 ],
#        [  36.     , 1517.9626 , 1031.184  ],
#        ...,
#        [1818.     , 1260.1796 , 1335.852  ],
#        [1813.9729 , 1265.544  , 1335.852  ],
#        [1818.3433 , 1253.826  , 1335.852  ]], dtype=float32)

# %% [markdown]
# Get the surface coordinates for the ventricle segmentation

# %%
from skimage.morphology import binary_erosion

# %%
foreground_eroded = binary_erosion(foreground)
surface_image = np.logical_and(foreground, ~foreground_eroded)

# %matplotlib inline
plt.figure()
plt.imshow(surface_image[210])
plt.show()

# %%
surface_coords = np.asarray(np.where(surface_image)).T
surface_coords.shape
# Out:
# (382646, 3)

# %%
surface_um = surface_coords * voxel_isotropic
surface_um.max(axis=0)
# Out:
# array([1800.666, 2980.278, 2913.876])

# %% [markdown]
# Find the nearest ventricle label for each mesh vertex

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nbrs = NearestNeighbors(n_neighbors=1).fit(surface_um)
nbrs
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=None, n_neighbors=1, p=2, radius=1.0)

# %%
distances, indices = nbrs.kneighbors(verts)
indices.shape, verts.shape
# Out:
# ((146834, 1), (146834, 3))

# %%
idx = indices[:, 0]
idx.shape
# Out:
# (146834,)

# %%
coords = surface_coords[idx]
coords.shape
# Out:
# (146834, 3)

# %%
coords_tuple = tuple([coords[:, i] for i in range(coords.shape[-1])])
coords_tuple
# Out:
# (array([ 11,  11,  11, ..., 460, 460, 460]),
#  array([389, 389, 389, ..., 320, 320, 320]),
#  array([264, 264, 264, ..., 340, 340, 340]))

# %%
ventricle_labels = labels[coords_tuple]
ventricle_labels.shape
# Out:
# (146834,)

# %%
f'All ventricles have matches? {ventricle_labels.max() == labels.max()}'
# Out:
# 'All ventricles have matches? True'

# %%
counts = np.bincount(ventricle_labels, minlength=labels.max()+1)[1:]
counts
# Out:
# array([  476,   678,   329,  2538,   133,  3694,   363,  1552,  2568,
#         3097,  5202,  2718,  5626, 12427,   840,  3160,  2784,    48,
#           42,   126,   146,  5662,  1684,   430,  1527,  2396,  2908,
#           85,   506,  2074,  1834,   664,  3368,  1670,   578,   148,
#          294,   159,   552,  1282,    98,  1363,  1420,   195,   333,
#         1888,  2132, 14241,   232,   870,  1100,  1778,   950,  1583,
#         1896,  1904,   338,   780,   470,  1454,   962,  2082,  1828,
#         1148,   960,  2422,  7327,  1920,  1388,  1220,  1194,   212,
#           17,  1568,  4984,  3734,  1524,   224,   114,    48,    91,
#          215,   149,   110])

# %%
all_cyto_labels = np.unique(cyto_labels)
all_cyto_labels
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
fractions = []
for lbl in range(1, labels.max()+1):
    idx = np.where(ventricle_labels == lbl)[0]
    ventricle_cytos = cyto_labels[idx]
    counts = np.bincount(ventricle_cytos, minlength=len(all_cyto_labels))
    fraction = counts / sum(counts)
    fractions.append(fraction)
fractions = np.asarray(fractions)
fractions.shape
# Out:
# (84, 6)

# %%
cyto_names = read_csv(os.path.join(working_dir, 'cyto_names.csv'))
cyto_names
# Out:
# ['TBR1-LowDN', 'TBR1-HighDN', 'Surface', 'Artifacts', 'DN', 'Adjacent']

# %%
sort_idx = np.argsort(fractions[:, 2]) #.astype('str')
fractions[sort_idx, -1]
# Out:
# array([0.4       , 0.77083333, 0.28187919, 0.26035503, 0.35326087,
#        0.74651163, 0.50638298, 0.66666667, 0.45116279, 0.25396825,
#        0.7266436 , 0.20945946, 0.74561404, 0.49319728, 0.39622642,
#        0.36734694, 0.57142857, 0.65625   , 0.58189655, 0.7173913 ,
#        0.22268908, 0.41176471, 0.26027397, 0.56545455, 0.46105263,
#        0.45143488, 0.54885655, 0.49090909, 0.00512821, 0.00600601,
#        0.2406015 , 0.58278689, 0.2079646 , 0.54094579, 0.53461538,
#        0.64880952, 0.56175772, 0.5921875 , 0.13069909, 0.73172713,
#        0.40405777, 0.57370184, 0.52048857, 0.6690682 , 0.59366197,
#        0.62964159, 0.55863039, 0.40929928, 0.68553459, 0.59270833,
#        0.60278746, 0.49905243, 0.47594937, 0.59811396, 0.59770115,
#        0.17396907, 0.31294537, 0.21179689, 0.31870781, 0.4430223 ,
#        0.42146974, 0.43801653, 0.5600624 , 0.52088913, 0.52475928,
#        0.40607424, 0.49179431, 0.54658841, 0.28850575, 0.47521097,
#        0.43941327, 0.42857143, 0.25945134, 0.43960084, 0.43008475,
#        0.47439759, 0.45367279, 0.42712407, 0.47164667, 0.33347377,
#        0.44314642, 0.40250795, 0.41676647, 0.34383202])

# %%
import pandas as pd
import seaborn as sns

# %%
frac_sum = np.cumsum(fractions, axis=-1)
frac_sum
# Out:
# array([[0.57563025, 0.58193277, 0.62394958, 0.64285714, 0.77731092,
#         1.        ],
#        [0.50589971, 0.62979351, 0.74483776, 0.74483776, 0.7920354 ,
#         1.        ],
#        [0.50151976, 0.6443769 , 0.79027356, 0.79027356, 0.86930091,
#         1.        ],
#        [0.15090623, 0.23719464, 0.4215918 , 0.47754137, 0.47951143,
#         1.        ],
#         1.        ],
#        [0.05165816, 0.14413265, 0.51211735, 0.51211735, 0.56058673,
#         1.        ],
#        [0.06661316, 0.12861156, 0.38523274, 0.38523274, 0.40188604,
#         1.        ],
#        [0.0690948 , 0.12372791, 0.4654526 , 0.4654526 , 0.47911087,
#         1.        ],
#        [0.04461942, 0.09251969, 0.65551181, 0.65551181, 0.65616798,
#         1.        ],
#        [0.07589286, 0.29017857, 0.32142857, 0.32142857, 0.34375   ,
#         1.        ],
#        [0.03508772, 0.23684211, 0.24561404, 0.24561404, 0.25438596,
#         1.        ],
#        [0.27083333, 0.29166667, 0.29166667, 0.29166667, 0.33333333,
#         1.        ],
#        [0.01098901, 0.40659341, 0.42857143, 0.42857143, 0.42857143,
#         1.        ],
#        [0.54883721, 0.54883721, 0.54883721, 0.54883721, 0.54883721,
#         1.        ],
#        [0.71812081, 0.71812081, 0.71812081, 0.71812081, 0.71812081,
#         1.        ],
#        [0.41818182, 0.41818182, 0.50909091, 0.50909091, 0.50909091,
#         1.        ]])

# %%
data = dict(zip(cyto_names, [frac_sum[sort_idx, i] for i in range(frac_sum.shape[-1])]))

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    TBR1-LowDN  TBR1-HighDN   Surface  Artifacts        DN  Adjacent
# 0    0.152941     0.341176  0.341176   0.600000  0.600000       1.0
# 1    0.083333     0.229167  0.229167   0.229167  0.229167       1.0
# 2    0.718121     0.718121  0.718121   0.718121  0.718121       1.0
# 3    0.517751     0.520710  0.520710   0.520710  0.739645       1.0
# 4    0.251812     0.251812  0.251812   0.251812  0.646739       1.0

# %%
plt.figure()
colors = ['r', 'b', 'k', 'y', 'g', 'c']
for i in range(len(cyto_names)):
    sns.barplot(x=df.index, y=cyto_names[-i-1], data=df, color=colors[i], label=cyto_names[-i-1])
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# Cyto fractions vs venrtricle size

# %%
# %matplotlib inline
plt.figure()
for i, name in enumerate(cyto_names):
    plt.semilogx(eq_diams_um, fractions[:, i], '.', label=name)
plt.legend()
plt.xlabel('Eq. diameter (um)')
plt.ylabel('Fraction')
plt.show()

# %%
data = dict(zip(cyto_names, [fractions[sort_idx, i] for i in range(frac_sum.shape[-1])]))
# data['idx'] = np.arange(119)
df = pd.DataFrame(data)
df.head()
# Out:
#    TBR1-LowDN  TBR1-HighDN  Surface  Artifacts        DN  Adjacent
# 0    0.152941     0.188235      0.0   0.258824  0.000000  0.400000
# 1    0.083333     0.145833      0.0   0.000000  0.000000  0.770833
# 2    0.718121     0.000000      0.0   0.000000  0.000000  0.281879
# 3    0.517751     0.002959      0.0   0.000000  0.218935  0.260355
# 4    0.251812     0.000000      0.0   0.000000  0.394928  0.353261

# %%
df['eq_diam'] = eq_diams_um
df['axis_ratio'] = axis_ratios
df['minor_axis'] = minor_axes_um
df['major_axis'] = major_axes_um
df['volume'] = volumes_um3
df.head()
# Out:
#    TBR1-LowDN  TBR1-HighDN  Surface  Artifacts        DN  Adjacent  \
# 0    0.152941     0.188235      0.0   0.258824  0.000000  0.400000
# 1    0.083333     0.145833      0.0   0.000000  0.000000  0.770833
# 2    0.718121     0.000000      0.0   0.000000  0.000000  0.281879
# 3    0.517751     0.002959      0.0   0.000000  0.218935  0.260355
# 4    0.251812     0.000000      0.0   0.000000  0.394928  0.353261
#
#       eq_diam  axis_ratio  minor_axis  major_axis        volume
# 0   64.338557    2.618064   56.544032  148.035902  1.394481e+05
# 1   83.226031    1.511037  120.257637  181.713695  3.018396e+05
# 2   58.366502    1.564621   64.184375  100.424189  1.041093e+05
# 3  166.898623    1.397866  195.603389  273.427311  2.434203e+06
# 4   21.555607    1.755925   30.997834   54.429868  5.244202e+03

# %%
plt.figure(figsize=(6, 6))
for i, name in enumerate(cyto_names):
    sns.regplot(x='eq_diam', y=name, data=df, scatter_kws={'alpha': 0.7, 's': 10}, label=name)
plt.xlim([0, 200])
plt.ylim([0, 0.8])
plt.legend()
plt.show()

# %% [markdown]
# Add in distance to surface

# %%
centers = np.asarray([region.centroid for region in regions]) * voxel_isotropic
centers.shape
# Out:
# (84, 3)

# %%
centers.max(axis=0)
# Out:
# array([1626.930375  , 2906.71654283, 2825.86404874])

# %%
overall_seg = io.imread(os.path.join(working_dir, 'dataset/segment_foreground.tif')) > 0
overall_seg.shape
# Out:
# (1200, 924, 924)

# %%
overall_seg.max()
# Out:
# True

# %%
org_surface = np.logical_and(overall_seg, ~binary_erosion(overall_seg))

# %%
# %matplotlib inline
plt.figure()
plt.imshow(org_surface[400])
plt.show()

# %%
org_surf_coords = np.asarray(np.where(org_surface)).T * voxel_down
org_surf_coords.max(axis=0)
# Out:
# array([1926.   , 3605.238, 3370.878])

# %%
nbrs = NearestNeighbors(n_neighbors=1).fit(org_surf_coords)
nbrs
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=None, n_neighbors=1, p=2, radius=1.0)

# %%
dist_surf, _ = nbrs.kneighbors(centers)

# %%
df['dist'] = dist_surf
df.head()
# Out:
#    TBR1-LowDN  TBR1-HighDN  Surface  Artifacts        DN  Adjacent  \
# 0    0.152941     0.188235      0.0   0.258824  0.000000  0.400000
# 1    0.083333     0.145833      0.0   0.000000  0.000000  0.770833
# 2    0.718121     0.000000      0.0   0.000000  0.000000  0.281879
# 3    0.517751     0.002959      0.0   0.000000  0.218935  0.260355
# 4    0.251812     0.000000      0.0   0.000000  0.394928  0.353261
#
#       eq_diam  axis_ratio  minor_axis  major_axis        volume        dist
# 0   64.338557    2.618064   56.544032  148.035902  1.394481e+05   76.131422
# 1   83.226031    1.511037  120.257637  181.713695  3.018396e+05  108.243836
# 2   58.366502    1.564621   64.184375  100.424189  1.041093e+05  158.130207
# 3  166.898623    1.397866  195.603389  273.427311  2.434203e+06  185.975468
# 4   21.555607    1.755925   30.997834   54.429868  5.244202e+03  195.563480

# %%
plt.figure(figsize=(6, 6))
for i, name in enumerate(cyto_names):
    sns.regplot(x='dist', y=name, data=df, scatter_kws={'alpha': 0.7, 's': 10}, label=name)
plt.xlim([100, 400])
plt.ylim([0, 0.8])
plt.xlabel('Distance to Surface')
plt.ylabel('Fraction')
plt.legend()
plt.show()

# %%
sns.regplot(x='dist', y='eq_diam', data=df)

# %%
df.to_excel(os.path.join(working_dir, 'individual_ventricle_cyto.xlsx'))
